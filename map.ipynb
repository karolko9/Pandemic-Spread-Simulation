# %%
# %pip install keplergl
# Out:
# Collecting keplergl
#   Downloading keplergl-0.3.6.tar.gz (18.4 MB)
#      ---------------------------------------- 0.0/18.4 MB ? eta -:--:--
#      --------------------------------------- 0.0/18.4 MB 330.3 kB/s eta 0:00:56
#      --------------------------------------- 0.0/18.4 MB 393.8 kB/s eta 0:00:47
#      --------------------------------------- 0.1/18.4 MB 655.4 kB/s eta 0:00:28
#       --------------------------------------- 0.4/18.4 MB 2.4 MB/s eta 0:00:08
#      - -------------------------------------- 0.8/18.4 MB 3.6 MB/s eta 0:00:05
#      -- ------------------------------------- 1.2/18.4 MB 4.6 MB/s eta 0:00:04
#      --- ------------------------------------ 1.8/18.4 MB 5.6 MB/s eta 0:00:03
#      ---- ----------------------------------- 2.3/18.4 MB 6.4 MB/s eta 0:00:03
#      ------ --------------------------------- 2.8/18.4 MB 7.0 MB/s eta 0:00:03
#      ------- -------------------------------- 3.4/18.4 MB 7.4 MB/s eta 0:00:03
#      -------- ------------------------------- 3.9/18.4 MB 8.1 MB/s eta 0:00:02
#      --------- ------------------------------ 4.5/18.4 MB 8.4 MB/s eta 0:00:02
#      ---------- ----------------------------- 5.0/18.4 MB 8.6 MB/s eta 0:00:02
#      ----------- ---------------------------- 5.5/18.4 MB 8.8 MB/s eta 0:00:02
#      ------------- -------------------------- 6.1/18.4 MB 9.0 MB/s eta 0:00:02
#      -------------- ------------------------- 6.6/18.4 MB 9.2 MB/s eta 0:00:02
#      --------------- ------------------------ 7.1/18.4 MB 9.2 MB/s eta 0:00:02
#      ---------------- ----------------------- 7.6/18.4 MB 9.3 MB/s eta 0:00:02
#      ----------------- ---------------------- 8.0/18.4 MB 9.3 MB/s eta 0:00:02
#      ------------------ --------------------- 8.5/18.4 MB 9.4 MB/s eta 0:00:02
#      ------------------- -------------------- 9.1/18.4 MB 9.5 MB/s eta 0:00:01
#      -------------------- ------------------- 9.6/18.4 MB 9.6 MB/s eta 0:00:01
#      ---------------------- ----------------- 10.2/18.4 MB 9.7 MB/s eta 0:00:01
#      ---------------------- ---------------- 10.7/18.4 MB 11.5 MB/s eta 0:00:01
#      ----------------------- --------------- 11.2/18.4 MB 11.5 MB/s eta 0:00:01
#      ------------------------ -------------- 11.8/18.4 MB 11.7 MB/s eta 0:00:01
#      -------------------------- ------------ 12.3/18.4 MB 11.7 MB/s eta 0:00:01
#      --------------------------- ----------- 12.9/18.4 MB 11.7 MB/s eta 0:00:01
#      ---------------------------- ---------- 13.4/18.4 MB 11.5 MB/s eta 0:00:01
#      ----------------------------- --------- 13.9/18.4 MB 11.5 MB/s eta 0:00:01
#      ------------------------------ -------- 14.4/18.4 MB 11.5 MB/s eta 0:00:01
#      ------------------------------- ------- 15.0/18.4 MB 11.5 MB/s eta 0:00:01
#      -------------------------------- ------ 15.5/18.4 MB 11.7 MB/s eta 0:00:01
#      --------------------------------- ----- 16.0/18.4 MB 11.7 MB/s eta 0:00:01
#      ----------------------------------- --- 16.6/18.4 MB 11.7 MB/s eta 0:00:01
#      ------------------------------------ -- 17.1/18.4 MB 11.7 MB/s eta 0:00:01
#      ------------------------------------- - 17.7/18.4 MB 11.7 MB/s eta 0:00:01
#      --------------------------------------  18.2/18.4 MB 11.9 MB/s eta 0:00:01
#      --------------------------------------  18.4/18.4 MB 11.9 MB/s eta 0:00:01
#      --------------------------------------- 18.4/18.4 MB 11.1 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: still running...
#   Installing build dependencies: still running...
#   Installing build dependencies: still running...
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting ipywidgets>=8.1.5 (from keplergl)
#   Obtaining dependency information for ipywidgets>=8.1.5 from https://files.pythonhosted.org/packages/22/2d/9c0b76f2f9cc0ebede1b9371b6f317243028ed60b90705863d493bae622e/ipywidgets-8.1.5-py3-none-any.whl.metadata
#   Using cached ipywidgets-8.1.5-py3-none-any.whl.metadata (2.3 kB)
# Collecting traittypes>=0.2.1 (from keplergl)
#   Obtaining dependency information for traittypes>=0.2.1 from https://files.pythonhosted.org/packages/9c/d1/8d5bd662703cc1764d986f6908a608777305946fa634d34c470cd4a1e729/traittypes-0.2.1-py2.py3-none-any.whl.metadata
#   Downloading traittypes-0.2.1-py2.py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: traitlets>=4.3.2 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from keplergl) (5.14.3)
# Collecting geopandas>=0.14.3 (from keplergl)
#   Obtaining dependency information for geopandas>=0.14.3 from https://files.pythonhosted.org/packages/c4/64/7d344cfcef5efddf9cf32f59af7f855828e9d74b5f862eddf5bfd9f25323/geopandas-1.0.1-py3-none-any.whl.metadata
#   Downloading geopandas-1.0.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting Shapely>=1.6.4.post2 (from keplergl)
#   Obtaining dependency information for Shapely>=1.6.4.post2 from https://files.pythonhosted.org/packages/7b/b3/857afd9dfbfc554f10d683ac412eac6fa260d1f4cd2967ecb655c57e831a/shapely-2.0.6-cp312-cp312-win_amd64.whl.metadata
#   Using cached shapely-2.0.6-cp312-cp312-win_amd64.whl.metadata (7.2 kB)
# Collecting jupyter_packaging>=0.12.3 (from keplergl)
#   Obtaining dependency information for jupyter_packaging>=0.12.3 from https://files.pythonhosted.org/packages/dd/cb/6c4c3e2219c2fe6fff6f9d4bda48da21951c3bd8f39b443a586f13173ea0/jupyter_packaging-0.12.3-py3-none-any.whl.metadata
#   Using cached jupyter_packaging-0.12.3-py3-none-any.whl.metadata (7.7 kB)
# Collecting jupyter>=1.0.0 (from keplergl)
#   Obtaining dependency information for jupyter>=1.0.0 from https://files.pythonhosted.org/packages/38/64/285f20a31679bf547b75602702f7800e74dbabae36ef324f716c02804753/jupyter-1.1.1-py2.py3-none-any.whl.metadata
#   Downloading jupyter-1.1.1-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: jupyterlab>=4.1.6 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from keplergl) (4.3.4)
# Requirement already satisfied: notebook>=6.0.1 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from keplergl) (7.3.2)
# Collecting pyarrow>=16.0.0 (from keplergl)
#   Obtaining dependency information for pyarrow>=16.0.0 from https://files.pythonhosted.org/packages/76/52/f8da04195000099d394012b8d42c503d7041b79f778d854f410e5f05049a/pyarrow-18.1.0-cp312-cp312-win_amd64.whl.metadata
#   Downloading pyarrow-18.1.0-cp312-cp312-win_amd64.whl.metadata (3.4 kB)
# Collecting geoarrow-pyarrow>=0.1.2 (from keplergl)
#   Obtaining dependency information for geoarrow-pyarrow>=0.1.2 from https://files.pythonhosted.org/packages/60/52/40a7257780bb68234790369c56d9d6f9e9e66a8cf940720de1215d01e533/geoarrow_pyarrow-0.1.2-py3-none-any.whl.metadata
#   Downloading geoarrow_pyarrow-0.1.2-py3-none-any.whl.metadata (613 bytes)
# Collecting geoarrow-pandas>=0.1.1 (from keplergl)
#   Obtaining dependency information for geoarrow-pandas>=0.1.1 from https://files.pythonhosted.org/packages/ed/88/c84e04447985d761ff616bda77722a2dae2c876f7e656a5674df58a9d309/geoarrow_pandas-0.1.1-py3-none-any.whl.metadata
#   Downloading geoarrow_pandas-0.1.1-py3-none-any.whl.metadata (493 bytes)
# Collecting pandas (from geoarrow-pandas>=0.1.1->keplergl)
#   Obtaining dependency information for pandas from https://files.pythonhosted.org/packages/29/d4/1244ab8edf173a10fd601f7e13b9566c1b525c4f365d6bee918e68381889/pandas-2.2.3-cp312-cp312-win_amd64.whl.metadata
#   Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting geoarrow-c (from geoarrow-pyarrow>=0.1.2->keplergl)
#   Obtaining dependency information for geoarrow-c from https://files.pythonhosted.org/packages/d1/10/ea22bbb0f71cb953444616a342a0f5a7b4cb68829efd94d7beff60d09232/geoarrow_c-0.1.2-cp312-cp312-win_amd64.whl.metadata
#   Downloading geoarrow_c-0.1.2-cp312-cp312-win_amd64.whl.metadata (413 bytes)
# Collecting pyarrow-hotfix (from geoarrow-pyarrow>=0.1.2->keplergl)
#   Obtaining dependency information for pyarrow-hotfix from https://files.pythonhosted.org/packages/e4/f4/9ec2222f5f5f8ea04f66f184caafd991a39c8782e31f5b0266f101cb68ca/pyarrow_hotfix-0.6-py3-none-any.whl.metadata
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl.metadata (3.6 kB)
# Collecting numpy>=1.22 (from geopandas>=0.14.3->keplergl)
#   Obtaining dependency information for numpy>=1.22 from https://files.pythonhosted.org/packages/17/c1/c31d3637f2641e25c7a19adf2ae822fdaf4ddd198b05d79a92a9ce7cb63e/numpy-2.2.1-cp312-cp312-win_amd64.whl.metadata
#   Using cached numpy-2.2.1-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting pyogrio>=0.7.2 (from geopandas>=0.14.3->keplergl)
#   Obtaining dependency information for pyogrio>=0.7.2 from https://files.pythonhosted.org/packages/43/97/34605480f06b0ad9611bf58a174eccc6f3673275f3d519cf763391892881/pyogrio-0.10.0-cp312-cp312-win_amd64.whl.metadata
#   Downloading pyogrio-0.10.0-cp312-cp312-win_amd64.whl.metadata (5.6 kB)
# Requirement already satisfied: packaging in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from geopandas>=0.14.3->keplergl) (24.2)
# Collecting pyproj>=3.3.0 (from geopandas>=0.14.3->keplergl)
#   Obtaining dependency information for pyproj>=3.3.0 from https://files.pythonhosted.org/packages/a1/8b/96bc8c8f3eca4eb7fa3758fde0b755d1df30a19f494376e3ee8de1ef4e79/pyproj-3.7.0-cp312-cp312-win_amd64.whl.metadata
#   Using cached pyproj-3.7.0-cp312-cp312-win_amd64.whl.metadata (31 kB)
# Requirement already satisfied: comm>=0.1.3 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from ipywidgets>=8.1.5->keplergl) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from ipywidgets>=8.1.5->keplergl) (8.31.0)
# Collecting widgetsnbextension~=4.0.12 (from ipywidgets>=8.1.5->keplergl)
#   Obtaining dependency information for widgetsnbextension~=4.0.12 from https://files.pythonhosted.org/packages/21/02/88b65cc394961a60c43c70517066b6b679738caf78506a5da7b88ffcb643/widgetsnbextension-4.0.13-py3-none-any.whl.metadata
#   Using cached widgetsnbextension-4.0.13-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.12 (from ipywidgets>=8.1.5->keplergl)
#   Obtaining dependency information for jupyterlab-widgets~=3.0.12 from https://files.pythonhosted.org/packages/a9/93/858e87edc634d628e5d752ba944c2833133a28fa87bb093e6832ced36a3e/jupyterlab_widgets-3.0.13-py3-none-any.whl.metadata
#   Using cached jupyterlab_widgets-3.0.13-py3-none-any.whl.metadata (4.1 kB)
# Collecting jupyter-console (from jupyter>=1.0.0->keplergl)
#   Obtaining dependency information for jupyter-console from https://files.pythonhosted.org/packages/ca/77/71d78d58f15c22db16328a476426f7ac4a60d3a5a7ba3b9627ee2f7903d4/jupyter_console-6.6.3-py3-none-any.whl.metadata
#   Downloading jupyter_console-6.6.3-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: nbconvert in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from jupyter>=1.0.0->keplergl) (7.16.5)
# Requirement already satisfied: ipykernel in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from jupyter>=1.0.0->keplergl) (6.29.5)
# Collecting deprecation (from jupyter_packaging>=0.12.3->keplergl)
#   Obtaining dependency information for deprecation from https://files.pythonhosted.org/packages/02/c3/253a89ee03fc9b9682f1541728eb66db7db22148cd94f89ab22528cd1e1b/deprecation-2.1.0-py2.py3-none-any.whl.metadata
#   Using cached deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: setuptools>=60.2.0 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from jupyter_packaging>=0.12.3->keplergl) (75.8.0)
# Collecting tomlkit (from jupyter_packaging>=0.12.3->keplergl)
#   Obtaining dependency information for tomlkit from https://files.pythonhosted.org/packages/f9/b6/a447b5e4ec71e13871be01ba81f5dfc9d0af7e473da256ff46bc0e24026f/tomlkit-0.13.2-py3-none-any.whl.metadata
#   Using cached tomlkit-0.13.2-py3-none-any.whl.metadata (2.7 kB)
# Collecting wheel (from jupyter_packaging>=0.12.3->keplergl)
#   Obtaining dependency information for wheel from https://files.pythonhosted.org/packages/0b/2c/87f3254fd8ffd29e4c02732eee68a83a1d3c346ae39bc6822dcbcb697f2b/wheel-0.45.1-py3-none-any.whl.metadata
#   Using cached wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: async-lru>=1.0.0 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from jupyterlab>=4.1.6->keplergl) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from jupyterlab>=4.1.6->keplergl) (0.28.1)
# Requirement already satisfied: jinja2>=3.0.3 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from jupyterlab>=4.1.6->keplergl) (3.1.5)
# Requirement already satisfied: jupyter-core in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from jupyterlab>=4.1.6->keplergl) (5.7.2)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from jupyterlab>=4.1.6->keplergl) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from jupyterlab>=4.1.6->keplergl) (2.15.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from jupyterlab>=4.1.6->keplergl) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from jupyterlab>=4.1.6->keplergl) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from jupyterlab>=4.1.6->keplergl) (6.4.2)
# Requirement already satisfied: anyio in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from httpx>=0.25.0->jupyterlab>=4.1.6->keplergl) (4.8.0)
# Requirement already satisfied: certifi in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from httpx>=0.25.0->jupyterlab>=4.1.6->keplergl) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from httpx>=0.25.0->jupyterlab>=4.1.6->keplergl) (1.0.7)
# Requirement already satisfied: idna in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from httpx>=0.25.0->jupyterlab>=4.1.6->keplergl) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab>=4.1.6->keplergl) (0.14.0)
# Requirement already satisfied: debugpy>=1.6.5 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from ipykernel->jupyter>=1.0.0->keplergl) (1.8.11)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from ipykernel->jupyter>=1.0.0->keplergl) (8.6.3)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from ipykernel->jupyter>=1.0.0->keplergl) (0.1.7)
# Requirement already satisfied: nest-asyncio in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from ipykernel->jupyter>=1.0.0->keplergl) (1.6.0)
# Requirement already satisfied: psutil in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from ipykernel->jupyter>=1.0.0->keplergl) (6.1.1)
# Requirement already satisfied: pyzmq>=24 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from ipykernel->jupyter>=1.0.0->keplergl) (26.2.0)
# Requirement already satisfied: colorama in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8.1.5->keplergl) (0.4.6)
# Requirement already satisfied: decorator in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8.1.5->keplergl) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8.1.5->keplergl) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8.1.5->keplergl) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8.1.5->keplergl) (2.19.1)
# Requirement already satisfied: stack_data in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8.1.5->keplergl) (0.6.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from jinja2>=3.0.3->jupyterlab>=4.1.6->keplergl) (3.0.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from jupyter-core->jupyterlab>=4.1.6->keplergl) (4.3.6)
# Requirement already satisfied: pywin32>=300 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from jupyter-core->jupyterlab>=4.1.6->keplergl) (308)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (0.11.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (0.5.3)
# Requirement already satisfied: nbformat>=5.3.0 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (0.21.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (2.0.14)
# Requirement already satisfied: send2trash>=1.8.2 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (1.8.0)
# Requirement already satisfied: babel>=2.10 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab>=4.1.6->keplergl) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab>=4.1.6->keplergl) (0.10.0)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab>=4.1.6->keplergl) (4.23.0)
# Requirement already satisfied: requests>=2.31 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab>=4.1.6->keplergl) (2.32.3)
# Requirement already satisfied: beautifulsoup4 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from nbconvert->jupyter>=1.0.0->keplergl) (4.12.3)
# Requirement already satisfied: bleach[css]!=5.0.0 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from nbconvert->jupyter>=1.0.0->keplergl) (6.2.0)
# Requirement already satisfied: defusedxml in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from nbconvert->jupyter>=1.0.0->keplergl) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from nbconvert->jupyter>=1.0.0->keplergl) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from nbconvert->jupyter>=1.0.0->keplergl) (3.1.0)
# Requirement already satisfied: nbclient>=0.5.0 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from nbconvert->jupyter>=1.0.0->keplergl) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from nbconvert->jupyter>=1.0.0->keplergl) (1.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from pandas->geoarrow-pandas>=0.1.1->keplergl) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas->geoarrow-pandas>=0.1.1->keplergl)
#   Obtaining dependency information for pytz>=2020.1 from https://files.pythonhosted.org/packages/11/c3/005fcca25ce078d2cc29fd559379817424e94885510568bc1bc53d7d5846/pytz-2024.2-py2.py3-none-any.whl.metadata
#   Using cached pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->geoarrow-pandas>=0.1.1->keplergl)
#   Obtaining dependency information for tzdata>=2022.7 from https://files.pythonhosted.org/packages/a6/ab/7e5f53c3b9d14972843a647d8d7a853969a58aecc7559cb3267302c94774/tzdata-2024.2-py2.py3-none-any.whl.metadata
#   Using cached tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: sniffio>=1.1 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from anyio->httpx>=0.25.0->jupyterlab>=4.1.6->keplergl) (1.3.1)
# Requirement already satisfied: typing_extensions>=4.5 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from anyio->httpx>=0.25.0->jupyterlab>=4.1.6->keplergl) (4.12.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (21.2.0)
# Requirement already satisfied: webencodings in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter>=1.0.0->keplergl) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter>=1.0.0->keplergl) (1.4.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=8.1.5->keplergl) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab>=4.1.6->keplergl) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab>=4.1.6->keplergl) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab>=4.1.6->keplergl) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab>=4.1.6->keplergl) (0.22.3)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (3.2.1)
# Requirement already satisfied: pyyaml>=5.3 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (6.0.2)
# Requirement already satisfied: rfc3339-validator in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (0.1.1)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (2.21.1)
# Requirement already satisfied: wcwidth in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=8.1.5->keplergl) (0.2.13)
# Requirement already satisfied: six>=1.5 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas->geoarrow-pandas>=0.1.1->keplergl) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab>=4.1.6->keplergl) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab>=4.1.6->keplergl) (2.3.0)
# Requirement already satisfied: soupsieve>1.2 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from beautifulsoup4->nbconvert->jupyter>=1.0.0->keplergl) (2.6)
# Requirement already satisfied: executing>=1.2.0 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=8.1.5->keplergl) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=8.1.5->keplergl) (3.0.0)
# Requirement already satisfied: pure-eval in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=8.1.5->keplergl) (0.2.3)
# Requirement already satisfied: fqdn in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab>=4.1.6->keplergl) (1.5.1)
# Requirement already satisfied: isoduration in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab>=4.1.6->keplergl) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab>=4.1.6->keplergl) (3.0.0)
# Requirement already satisfied: uri-template in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab>=4.1.6->keplergl) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab>=4.1.6->keplergl) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (1.17.1)
# Requirement already satisfied: pycparser in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from isoduration->jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab>=4.1.6->keplergl) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab>=4.1.6->keplergl) (2.9.0.20241206)
# Downloading geoarrow_pandas-0.1.1-py3-none-any.whl (6.2 kB)
# Downloading geoarrow_pyarrow-0.1.2-py3-none-any.whl (26 kB)
# Downloading geopandas-1.0.1-py3-none-any.whl (323 kB)
#    ---------------------------------------- 0.0/323.6 kB ? eta -:--:--
#    ---------------------------------------- 323.6/323.6 kB 9.8 MB/s eta 0:00:00
# Using cached ipywidgets-8.1.5-py3-none-any.whl (139 kB)
# Downloading jupyter-1.1.1-py2.py3-none-any.whl (2.7 kB)
# Using cached jupyter_packaging-0.12.3-py3-none-any.whl (15 kB)
# Downloading pyarrow-18.1.0-cp312-cp312-win_amd64.whl (25.1 MB)
#    ---------------------------------------- 0.0/25.1 MB ? eta -:--:--
#     --------------------------------------- 0.6/25.1 MB 18.2 MB/s eta 0:00:02
#    - -------------------------------------- 1.2/25.1 MB 12.3 MB/s eta 0:00:02
#    -- ------------------------------------- 1.7/25.1 MB 12.0 MB/s eta 0:00:02
#    --- ------------------------------------ 2.3/25.1 MB 13.2 MB/s eta 0:00:02
#    ---- ----------------------------------- 2.8/25.1 MB 12.1 MB/s eta 0:00:02
#    ----- ---------------------------------- 3.4/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.0/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 12.1 MB/s eta 0:00:02
#    ------ --------------------------------- 4.2/25.1 MB 1.1 MB/s eta 0:00:19
#    ------- -------------------------------- 4.8/25.1 MB 1.3 MB/s eta 0:00:17
#    -------- ------------------------------- 5.4/25.1 MB 1.4 MB/s eta 0:00:15
#    --------- ------------------------------ 5.9/25.1 MB 1.5 MB/s eta 0:00:13
#    ---------- ----------------------------- 6.5/25.1 MB 1.6 MB/s eta 0:00:12
#    ----------- ---------------------------- 7.1/25.1 MB 1.8 MB/s eta 0:00:11
#    ------------ --------------------------- 7.6/25.1 MB 1.9 MB/s eta 0:00:10
#    ------------- -------------------------- 8.2/25.1 MB 2.0 MB/s eta 0:00:09
#    -------------- ------------------------- 8.8/25.1 MB 2.1 MB/s eta 0:00:08
#    -------------- ------------------------- 9.4/25.1 MB 2.2 MB/s eta 0:00:08
#    --------------- ------------------------ 9.7/25.1 MB 2.3 MB/s eta 0:00:07
#    --------------- ------------------------ 10.0/25.1 MB 2.3 MB/s eta 0:00:07
#    ---------------- ----------------------- 10.3/25.1 MB 2.4 MB/s eta 0:00:07
#    ---------------- ----------------------- 10.5/25.1 MB 2.3 MB/s eta 0:00:07
#    ---------------- ----------------------- 10.6/25.1 MB 2.3 MB/s eta 0:00:07
#    ---------------- ----------------------- 10.7/25.1 MB 2.3 MB/s eta 0:00:07
#    ----------------- ---------------------- 10.7/25.1 MB 2.3 MB/s eta 0:00:07
#    ----------------- ---------------------- 10.9/25.1 MB 2.3 MB/s eta 0:00:07
#    ----------------- ---------------------- 11.0/25.1 MB 2.2 MB/s eta 0:00:07
#    ----------------- ---------------------- 11.1/25.1 MB 2.2 MB/s eta 0:00:07
#    ----------------- ---------------------- 11.3/25.1 MB 2.2 MB/s eta 0:00:07
#    ------------------ --------------------- 11.5/25.1 MB 2.2 MB/s eta 0:00:07
#    ------------------ --------------------- 11.6/25.1 MB 2.2 MB/s eta 0:00:07
#    ------------------ --------------------- 11.8/25.1 MB 2.2 MB/s eta 0:00:07
#    ------------------ --------------------- 11.9/25.1 MB 2.1 MB/s eta 0:00:07
#    ------------------- -------------------- 12.0/25.1 MB 2.1 MB/s eta 0:00:07
#    ------------------- -------------------- 12.2/25.1 MB 2.1 MB/s eta 0:00:07
#    ------------------- -------------------- 12.4/25.1 MB 2.1 MB/s eta 0:00:07
#    -------------------- ------------------- 12.6/25.1 MB 2.1 MB/s eta 0:00:06
#    -------------------- ------------------- 13.0/25.1 MB 2.1 MB/s eta 0:00:06
#    --------------------- ------------------ 13.4/25.1 MB 2.1 MB/s eta 0:00:06
#    --------------------- ------------------ 13.8/25.1 MB 2.1 MB/s eta 0:00:06
#    ---------------------- ----------------- 14.3/25.1 MB 2.1 MB/s eta 0:00:06
#    ----------------------- ---------------- 14.7/25.1 MB 6.6 MB/s eta 0:00:02
#    ----------------------- ---------------- 14.7/25.1 MB 6.6 MB/s eta 0:00:02
#    ----------------------- ---------------- 14.8/25.1 MB 6.2 MB/s eta 0:00:02
#    ------------------------ --------------- 15.2/25.1 MB 6.2 MB/s eta 0:00:02
#    ------------------------- -------------- 15.9/25.1 MB 6.2 MB/s eta 0:00:02
#    -------------------------- ------------- 16.4/25.1 MB 6.2 MB/s eta 0:00:02
#    --------------------------- ------------ 17.0/25.1 MB 6.2 MB/s eta 0:00:02
#    --------------------------- ------------ 17.6/25.1 MB 6.2 MB/s eta 0:00:02
#    ---------------------------- ----------- 18.1/25.1 MB 6.2 MB/s eta 0:00:02
#    ----------------------------- ---------- 18.7/25.1 MB 6.2 MB/s eta 0:00:02
#    ------------------------------ --------- 19.3/25.1 MB 6.2 MB/s eta 0:00:01
#    ------------------------------- -------- 19.8/25.1 MB 6.2 MB/s eta 0:00:01
#    -------------------------------- ------- 20.4/25.1 MB 6.4 MB/s eta 0:00:01
#    --------------------------------- ------ 21.0/25.1 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 21.5/25.1 MB 7.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 22.1/25.1 MB 8.7 MB/s eta 0:00:01
#    ------------------------------------ --- 22.7/25.1 MB 9.9 MB/s eta 0:00:01
#    ------------------------------------- -- 23.2/25.1 MB 10.2 MB/s eta 0:00:01
#    ------------------------------------- -- 23.8/25.1 MB 10.4 MB/s eta 0:00:01
#    -------------------------------------- - 24.4/25.1 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------  25.0/25.1 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------  25.1/25.1 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------- 25.1/25.1 MB 11.1 MB/s eta 0:00:00
# Using cached shapely-2.0.6-cp312-cp312-win_amd64.whl (1.4 MB)
# Downloading traittypes-0.2.1-py2.py3-none-any.whl (8.6 kB)
# Using cached jupyterlab_widgets-3.0.13-py3-none-any.whl (214 kB)
# Using cached numpy-2.2.1-cp312-cp312-win_amd64.whl (12.6 MB)
# Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl (11.5 MB)
# Downloading pyogrio-0.10.0-cp312-cp312-win_amd64.whl (16.2 MB)
#    ---------------------------------------- 0.0/16.2 MB ? eta -:--:--
#    - -------------------------------------- 0.6/16.2 MB 17.5 MB/s eta 0:00:01
#    -- ------------------------------------- 1.1/16.2 MB 13.5 MB/s eta 0:00:02
#    --- ------------------------------------ 1.5/16.2 MB 11.6 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.9/16.2 MB 9.9 MB/s eta 0:00:02
#    ----- ---------------------------------- 2.3/16.2 MB 9.7 MB/s eta 0:00:02
#    ------ --------------------------------- 2.7/16.2 MB 10.1 MB/s eta 0:00:02
#    ------- -------------------------------- 3.1/16.2 MB 9.4 MB/s eta 0:00:02
#    -------- ------------------------------- 3.5/16.2 MB 9.3 MB/s eta 0:00:02
#    --------- ------------------------------ 3.9/16.2 MB 9.3 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.2/16.2 MB 9.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.2/16.2 MB 9.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.2/16.2 MB 9.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.2/16.2 MB 9.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.2/16.2 MB 9.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.2/16.2 MB 9.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.2/16.2 MB 9.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.2/16.2 MB 9.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.2/16.2 MB 9.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.2/16.2 MB 9.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.2/16.2 MB 9.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.2/16.2 MB 9.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.2/16.2 MB 9.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.2/16.2 MB 9.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.2/16.2 MB 9.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.2/16.2 MB 9.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.2/16.2 MB 9.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.2/16.2 MB 9.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.2/16.2 MB 9.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.2/16.2 MB 9.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.2/16.2 MB 9.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.2/16.2 MB 9.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.2/16.2 MB 9.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.2/16.2 MB 9.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.2/16.2 MB 9.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.2/16.2 MB 9.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.2/16.2 MB 9.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.2/16.2 MB 9.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.2/16.2 MB 9.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.2/16.2 MB 9.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.2/16.2 MB 9.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.2/16.2 MB 9.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.2/16.2 MB 9.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.2/16.2 MB 9.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.2/16.2 MB 9.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.2/16.2 MB 9.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.2/16.2 MB 9.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.3/16.2 MB 1.9 MB/s eta 0:00:07
#    ----------- ---------------------------- 4.6/16.2 MB 2.0 MB/s eta 0:00:06
#    ------------ --------------------------- 4.9/16.2 MB 2.1 MB/s eta 0:00:06
#    ------------- -------------------------- 5.3/16.2 MB 2.2 MB/s eta 0:00:05
#    ------------- -------------------------- 5.6/16.2 MB 2.3 MB/s eta 0:00:05
#    -------------- ------------------------- 5.9/16.2 MB 2.4 MB/s eta 0:00:05
#    --------------- ------------------------ 6.1/16.2 MB 2.4 MB/s eta 0:00:05
#    --------------- ------------------------ 6.4/16.2 MB 2.5 MB/s eta 0:00:04
#    ---------------- ----------------------- 6.8/16.2 MB 2.6 MB/s eta 0:00:04
#    ------------------ --------------------- 7.3/16.2 MB 2.7 MB/s eta 0:00:04
#    ------------------- -------------------- 7.7/16.2 MB 2.9 MB/s eta 0:00:03
#    -------------------- ------------------- 8.2/16.2 MB 3.0 MB/s eta 0:00:03
#    --------------------- ------------------ 8.6/16.2 MB 3.1 MB/s eta 0:00:03
#    ---------------------- ----------------- 9.1/16.2 MB 3.2 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ----------------------- ---------------- 9.4/16.2 MB 3.3 MB/s eta 0:00:03
#    ------------------------ --------------- 9.8/16.2 MB 1.4 MB/s eta 0:00:05
#    ------------------------- -------------- 10.2/16.2 MB 1.5 MB/s eta 0:00:05
#    -------------------------- ------------- 10.7/16.2 MB 1.5 MB/s eta 0:00:04
#    --------------------------- ------------ 11.2/16.2 MB 1.5 MB/s eta 0:00:04
#    ---------------------------- ----------- 11.6/16.2 MB 1.5 MB/s eta 0:00:04
#    ----------------------------- ---------- 12.1/16.2 MB 1.5 MB/s eta 0:00:03
#    ------------------------------ --------- 12.2/16.2 MB 1.5 MB/s eta 0:00:03
#    ------------------------------- -------- 12.6/16.2 MB 1.5 MB/s eta 0:00:03
#    -------------------------------- ------- 13.0/16.2 MB 1.5 MB/s eta 0:00:03
#    --------------------------------- ------ 13.5/16.2 MB 1.5 MB/s eta 0:00:02
#    ---------------------------------- ----- 14.0/16.2 MB 1.5 MB/s eta 0:00:02
#    ----------------------------------- ---- 14.5/16.2 MB 2.0 MB/s eta 0:00:01
#    ------------------------------------- -- 15.0/16.2 MB 2.0 MB/s eta 0:00:01
#    -------------------------------------- - 15.5/16.2 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  16.1/16.2 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 16.2/16.2 MB 2.0 MB/s eta 0:00:00
# Using cached pyproj-3.7.0-cp312-cp312-win_amd64.whl (6.2 MB)
# Using cached widgetsnbextension-4.0.13-py3-none-any.whl (2.3 MB)
# Using cached deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Downloading geoarrow_c-0.1.2-cp312-cp312-win_amd64.whl (431 kB)
#    ---------------------------------------- 0.0/431.3 kB ? eta -:--:--
#    --------------------------------------- 431.3/431.3 kB 13.6 MB/s eta 0:00:00
# Downloading jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Downloading pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Using cached tomlkit-0.13.2-py3-none-any.whl (37 kB)
# Using cached wheel-0.45.1-py3-none-any.whl (72 kB)
# Using cached pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Using cached tzdata-2024.2-py2.py3-none-any.whl (346 kB)
# Building wheels for collected packages: keplergl
#   Building wheel for keplergl (pyproject.toml): started
#   Building wheel for keplergl (pyproject.toml): finished with status 'done'
#   Created wheel for keplergl: filename=keplergl-0.3.6-py2.py3-none-any.whl size=35080352 sha256=2fa799d45448bc8c16d955e0c9a71b28d2f58fa65d62a4af4db63028f388bde9
#   Stored in directory: c:\users\mkowa\appdata\local\pip\cache\wheels\a5\45\42\be9c01af8a947877bc82236868ce08ed5f0241143493316983
# Successfully built keplergl
# Installing collected packages: pytz, widgetsnbextension, wheel, tzdata, traittypes, tomlkit, pyproj, pyarrow-hotfix, pyarrow, numpy, jupyterlab-widgets, geoarrow-c, deprecation, Shapely, pyogrio, pandas, jupyter_packaging, geoarrow-pyarrow, ipywidgets, geopandas, geoarrow-pandas, jupyter-console, jupyter, keplergl
# Successfully installed Shapely-2.0.6 deprecation-2.1.0 geoarrow-c-0.1.2 geoarrow-pandas-0.1.1 geoarrow-pyarrow-0.1.2 geopandas-1.0.1 ipywidgets-8.1.5 jupyter-1.1.1 jupyter-console-6.6.3 jupyter_packaging-0.12.3 jupyterlab-widgets-3.0.13 keplergl-0.3.6 numpy-2.2.1 pandas-2.2.3 pyarrow-18.1.0 pyarrow-hotfix-0.6 pyogrio-0.10.0 pyproj-3.7.0 pytz-2024.2 tomlkit-0.13.2 traittypes-0.2.1 tzdata-2024.2 wheel-0.45.1 widgetsnbextension-4.0.13
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install pydeck pandas h3 geopandas
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting pydeck
#   Obtaining dependency information for pydeck from https://files.pythonhosted.org/packages/ab/4c/b888e6cf58bd9db9c93f40d1c6be8283ff49d88919231afe93a6bcf61626/pydeck-0.9.1-py2.py3-none-any.whl.metadata
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: pandas in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (2.2.3)
# Collecting h3
#   Obtaining dependency information for h3 from https://files.pythonhosted.org/packages/34/8f/7d5905e44f8aa5ca047d54737a37267e10be2108b455689539611b59b6ff/h3-4.1.2-cp312-cp312-win_amd64.whl.metadata
#   Downloading h3-4.1.2-cp312-cp312-win_amd64.whl.metadata (18 kB)
# Requirement already satisfied: geopandas in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (1.0.1)
# Requirement already satisfied: jinja2>=2.10.1 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from pydeck) (3.1.5)
# Requirement already satisfied: numpy>=1.16.4 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from pydeck) (2.2.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from geopandas) (0.10.0)
# Requirement already satisfied: packaging in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from geopandas) (24.2)
# Requirement already satisfied: pyproj>=3.3.0 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from geopandas) (3.7.0)
# Requirement already satisfied: shapely>=2.0.0 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from geopandas) (2.0.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from jinja2>=2.10.1->pydeck) (3.0.2)
# Requirement already satisfied: certifi in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from pyogrio>=0.7.2->geopandas) (2024.12.14)
# Requirement already satisfied: six>=1.5 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ---------------------------------------- 0.0/6.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/6.9 MB ? eta -:--:--
#    ---------------------------------------- 0.1/6.9 MB 1.2 MB/s eta 0:00:06
#    - -------------------------------------- 0.3/6.9 MB 2.6 MB/s eta 0:00:03
#    --- ------------------------------------ 0.6/6.9 MB 4.0 MB/s eta 0:00:02
#    ------ --------------------------------- 1.1/6.9 MB 5.3 MB/s eta 0:00:02
#    ------- -------------------------------- 1.3/6.9 MB 5.8 MB/s eta 0:00:01
#    --------- ------------------------------ 1.6/6.9 MB 5.5 MB/s eta 0:00:01
#    ---------- ----------------------------- 1.8/6.9 MB 5.5 MB/s eta 0:00:01
#    ------------- -------------------------- 2.4/6.9 MB 6.1 MB/s eta 0:00:01
#    ---------------- ----------------------- 2.9/6.9 MB 6.7 MB/s eta 0:00:01
#    ------------------ --------------------- 3.1/6.9 MB 6.7 MB/s eta 0:00:01
#    -------------------- ------------------- 3.5/6.9 MB 6.7 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.1/6.9 MB 7.0 MB/s eta 0:00:01
#    -------------------------- ------------- 4.6/6.9 MB 7.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.2/6.9 MB 7.7 MB/s eta 0:00:01
#    --------------------------------- ------ 5.7/6.9 MB 7.9 MB/s eta 0:00:01
#    ------------------------------------ --- 6.2/6.9 MB 8.1 MB/s eta 0:00:01
#    ---------------------------------------  6.8/6.9 MB 8.5 MB/s eta 0:00:01
#    ---------------------------------------- 6.9/6.9 MB 8.2 MB/s eta 0:00:00
# Downloading h3-4.1.2-cp312-cp312-win_amd64.whl (781 kB)
#    ---------------------------------------- 0.0/781.4 kB ? eta -:--:--
#    ------------------------- ------------- 501.8/781.4 kB 15.9 MB/s eta 0:00:01
#    ---------------------------------------  778.2/781.4 kB 9.8 MB/s eta 0:00:01
#    ---------------------------------------- 781.4/781.4 kB 8.2 MB/s eta 0:00:00
# Installing collected packages: h3, pydeck
# Successfully installed h3-4.1.2 pydeck-0.9.1
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import geopandas as gpd
from keplergl import KeplerGl

# %%
class Disease:
    def __init__(self):
        self.transmission_rate = 0.01
        self.incubation_rate = 0.05
        self.recovery_rate = 0.01
        self.mortality_rate = 0.015

    def seir_rates(self):
        return self.transmission_rate, self.incubation_rate, self.recovery_rate, self.mortality_rate

# %%
import random


class PandemicSpreadSimulation:
    def __init__(self):
        gdf = gpd.read_file('kontur_population_20231101_r4.gpkg')

        gdf = gdf[gdf['population'] > 50]

        # Upewnij się, że dane są w odpowiednim układzie współrzędnych (WGS84)
        gdf = gdf.to_crs(epsg=4326)

        # Dodaj pola SEIR do danych
        gdf['S'] = gdf['population']  # Wszyscy początkowo podatni
        gdf['E'] = 0  # Początkowo brak osób narażonych
        gdf['I'] = 0  # Początkowo brak osób zakażonych
        gdf['R'] = 0  # Początkowo brak ozdrowieńców
        gdf['V'] = 0  # Początkowo brak zaszczepionych
        gdf['airport'] = False
        gdf['masks'] = False
        gdf['lockdown'] = 0
        gdf['vaccinations'] = False

        target_hex_id = '846026bffffffff'
        target_hex = gdf[gdf['h3'] == target_hex_id]

        if not target_hex.empty:
            # Przenieś połowę osób z S do I
            half_S = target_hex['S'].values[0] // 2
            gdf.loc[gdf['h3'] == target_hex_id, 'I'] = half_S
            gdf.loc[gdf['h3'] == target_hex_id, 'S'] = target_hex['S'].values[0] - half_S
        else:
            print('No target hex found')

        self.gdf = gdf
        self.disease = Disease()

    def infect_neighbors(self):
        for index, row in self.gdf.iterrows():
            infected = row['I']
            if infected == 0:
                continue

            neighbors = self.gdf[self.gdf.geometry.touches(row.geometry)]

            for neighbor_index, neighbor in neighbors.iterrows():
                neighbor_S = neighbor['S']
                neighbor_population = neighbor['population']

                transmission_probability = 1 - ((1 - infected / row['population']) ** 5)

                is_transmitted = random.random() < transmission_probability
                if is_transmitted:
                    # Przenieś część osób z S do E w sąsiedniej populacji
                    new_exposed = random.randint(1, 10)  # Zakładamy losową liczbę nowych narażonych
                    actual_exposed = min(new_exposed, neighbor_S)  # Nie więcej niż dostępni w S

                    self.gdf.at[neighbor_index, 'S'] -= actual_exposed
                    self.gdf.at[neighbor_index, 'E'] += actual_exposed

        print("Neighbor infections processed.")

    # update simulation state by a day
    def update_simulation(self):
        self.infect_neighbors()

        flights_per_day = 10000
        for _ in range(flights_per_day):
            self.simulate_flight()

        transmission_rate, incubation_rate, recovery_rate, mortality_rate = self.disease.seir_rates()

        for index, row in self.gdf.iterrows():
            S = row['S']
            E = row['E']
            I = row['I']
            R = row['R']
            population = row['population']
            lockdown_days = row['lockdown']

            if lockdown_days > 0:
                self.gdf.at[index, 'lockdown'] = lockdown_days - 1

            # lockdown condition
            if I > population * 0.2 and lockdown_days == 0:
                self.gdf.at[index, 'lockdown'] = 30

            lockdown_transmission_reduce_rate = 0.01
            transmission_rate *= lockdown_transmission_reduce_rate

            new_exposed = int(transmission_rate * S * I / population)
            new_infected = int(incubation_rate * E)
            new_recovered = int(recovery_rate * I)
            new_dead = int(mortality_rate * I)

            # Zaktualizuj wartości SEIR
            new_S = S - new_exposed
            if new_S < 0:
                new_S = 0

            new_E = E + new_exposed - new_infected
            if new_E < 0:
                new_E = 0

            new_I = I + new_infected - new_recovered - new_dead
            if new_I < 0:
                new_I = 0

            new_R = R + new_recovered
            if new_R < 0:
                new_R = 0

            # Uaktualnij dane w gdf
            self.gdf.at[index, 'S'] = new_S
            self.gdf.at[index, 'E'] = new_E
            self.gdf.at[index, 'I'] = new_I
            self.gdf.at[index, 'R'] = new_R

    def simulate_flight(self):
        # Wybierz populacje z lotniskami bez lockdownu
        airports = self.gdf[(self.gdf['airport'] == True) & (self.gdf['lockdown'] == False)]
        if len(airports) < 2:
            return

        origin, destination = airports.sample(2)

        passengers = random.randint(100, 300)

        # Oblicz prawdopodobieństwo, że samolot jest zainfekowany
        infected_probability = 1 - ((1 - origin['E'] / origin['population']) ** passengers)

        # Losuj, czy samolot jest zainfekowany
        is_infected = random.random() < infected_probability

        if is_infected:
            # Jeśli samolot jest zainfekowany, przenieś pasażerów z S do E w docelowej populacji
            destination_S = self.gdf.at[destination.name, 'S']
            new_exposed = min(passengers, destination_S)  # Nie więcej niż S

            self.gdf.at[destination.name, 'S'] -= new_exposed
            self.gdf.at[destination.name, 'E'] += new_exposed

        print(f"Flight from {origin['h3']} to {destination['h3']}")
        print(f"Passengers: {passengers}")
        print(f"Plane infected: {'Yes' if is_infected else 'No'}")

# %%
def create_map_with_seir(gdf, filename='kepler_map_seir.html'):
    # Wczytaj dane granic państw
    countries = gpd.read_file("ne_110m_admin_0_countries.shp")  # Granice państw z Natural Earth
    countries.set_crs(epsg=4326, inplace=True)

    # Wczytaj dane miast
    cities = gpd.read_file("ne_110m_populated_places.shp")  # Miasta z Natural Earth
    cities.set_crs(epsg=4326, inplace=True)

    # Zaktualizuj konfigurację mapy
    config = {
        "version": "v1",
        "config": {
            "visState": {
                "filters": [],
                "layers": [
                    # Warstwa H3 Hexagony (jeśli używasz danych H3)
                    {
                        "id": "h3layer",
                        "type": "hexagonId",
                        "config": {
                            "dataId": "population_data",
                            "label": "H3 Hexagons",
                            "color": [0, 255, 0],  # Początkowy kolor zielony
                            "columns": {
                                "hex_id": "h3_index"
                            },
                            "isVisible": True,
                            "visConfig": {
                                "opacity": 0.8,
                                "colorRange": {
                                    "name": "Custom Gradient",
                                    "type": "sequential",
                                    "category": "Custom",
                                    "colors": ["#00FF00", "#FFA500"]  # Od zielonego do pomarańczowego
                                },
                                "coverage": 1,
                                "enable3d": True,
                                "sizeRange": [0, 500],
                                "coverageRange": [0, 1],
                                "elevationScale": 5
                            },
                        },
                        "visualChannels": {
                            "colorField": {
                                "name": "I",  # Użyj liczby zakażonych jako podstawy koloru
                                "type": "real"
                            },
                            "colorScale": "quantile",
                            "sizeField": {
                                "name": "population",
                                "type": "real"
                            },
                            "sizeScale": "linear"
                        }
                    },
                    # Warstwa GeoJSON (jeśli chcesz wyświetlać granice państw w formacie GeoJSON)
                    {
                        "id": "geojsonlayer",
                        "type": "geojson",
                        "config": {
                            "dataId": "countries",
                            "label": "Countries",
                            "color": [200, 200, 200],  # Ustaw kolor konturów na szary
                            "columns": {
                                "geojson": "geometry"
                            },
                            "isVisible": True,
                            "visConfig": {
                                "opacity": 0.8,
                                "colorRange": {
                                    "name": "Global Warming",
                                    "type": "sequential",
                                    "category": "Uber",
                                    "colors": ["#D3D3D3", "#D3D3D3"]  # Jasno szary
                                },
                                "coverage": 1
                            }
                        }
                    },
                    # Warstwa Miast
                    {
                        "id": "cityLayer",
                        "type": "geojson",
                        "config": {
                            "dataId": "cities",
                            "label": "Cities",
                            "color": [255, 0, 0],  # Kolor czerwony dla miast
                            "columns": {
                                "geojson": "geometry"
                            },
                            "isVisible": True
                        }
                    }
                ]
            },
            "mapState": {
                "bearing": 0,
                "latitude": 0,
                "longitude": 0,
                "pitch": 45,
                "zoom": 2,
                "dragRotate": True
            },
            "mapStyle": {
                "styleType": "dark",
                "topLayerGroups": {},
                "visibleLayerGroups": {
                    "label": True,
                    "road": True,
                    "border": True,  # Włącz granice
                    "building": True,
                    "water": True,
                    "land": True
                }
            }
        }
    }

    # Stwórz mapę z określoną wysokością
    map_1 = KeplerGl(height=800)

    # Dodaj dane do mapy
    map_1.add_data(data=gdf, name='population_data')
    map_1.add_data(data=countries, name="Countries")
    map_1.add_data(data=cities, name="Cities")

    # Zastosuj konfigurację
    map_1.config = config

    # Zapisz do pliku HTML
    map_1.save_to_html(file_name=filename)

    print("Mapa została zapisana! Otwórz plik kepler_map_seir.html w przeglądarce.")

testing = False
if testing:
    simulation = PandemicSpreadSimulation()
    create_map_with_seir(simulation.gdf)

# %%
simulation = PandemicSpreadSimulation()
create_map_with_seir(simulation.gdf, 'day0.html')
for i in range(2):
    simulation.update_simulation()
    create_map_with_seir(simulation.gdf, f'day{i + 1}.html')
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# Map saved to day0.html!
# Mapa została zapisana! Otwórz plik kepler_map_seir.html w przeglądarce.
# Neighbor infections processed.
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# Map saved to day1.html!
# Mapa została zapisana! Otwórz plik kepler_map_seir.html w przeglądarce.
# Neighbor infections processed.
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# Map saved to day2.html!
# Mapa została zapisana! Otwórz plik kepler_map_seir.html w przeglądarce.
