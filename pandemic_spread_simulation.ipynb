# %%
# %pip install keplergl
# Out:
# Requirement already satisfied: keplergl in c:\users\bolek\anaconda3\lib\site-packages (0.3.6)
# Requirement already satisfied: ipywidgets>=8.1.5 in c:\users\bolek\anaconda3\lib\site-packages (from keplergl) (8.1.5)
# Requirement already satisfied: traittypes>=0.2.1 in c:\users\bolek\anaconda3\lib\site-packages (from keplergl) (0.2.1)
# Requirement already satisfied: traitlets>=4.3.2 in c:\users\bolek\anaconda3\lib\site-packages (from keplergl) (5.14.3)
# Requirement already satisfied: geopandas>=0.14.3 in c:\users\bolek\anaconda3\lib\site-packages (from keplergl) (1.0.1)
# Requirement already satisfied: Shapely>=1.6.4.post2 in c:\users\bolek\anaconda3\lib\site-packages (from keplergl) (2.0.6)
# Requirement already satisfied: jupyter_packaging>=0.12.3 in c:\users\bolek\anaconda3\lib\site-packages (from keplergl) (0.12.3)
# Requirement already satisfied: jupyter>=1.0.0 in c:\users\bolek\anaconda3\lib\site-packages (from keplergl) (1.0.0)
# Requirement already satisfied: jupyterlab>=4.1.6 in c:\users\bolek\anaconda3\lib\site-packages (from keplergl) (4.3.4)
# Requirement already satisfied: notebook>=6.0.1 in c:\users\bolek\anaconda3\lib\site-packages (from keplergl) (7.3.2)
# Requirement already satisfied: pyarrow>=16.0.0 in c:\users\bolek\anaconda3\lib\site-packages (from keplergl) (18.1.0)
# Requirement already satisfied: geoarrow-pyarrow>=0.1.2 in c:\users\bolek\anaconda3\lib\site-packages (from keplergl) (0.1.2)
# Requirement already satisfied: geoarrow-pandas>=0.1.1 in c:\users\bolek\anaconda3\lib\site-packages (from keplergl) (0.1.1)
# Requirement already satisfied: pandas in c:\users\bolek\anaconda3\lib\site-packages (from geoarrow-pandas>=0.1.1->keplergl) (2.2.2)
# Requirement already satisfied: geoarrow-c in c:\users\bolek\anaconda3\lib\site-packages (from geoarrow-pyarrow>=0.1.2->keplergl) (0.1.2)
# Requirement already satisfied: pyarrow-hotfix in c:\users\bolek\anaconda3\lib\site-packages (from geoarrow-pyarrow>=0.1.2->keplergl) (0.6)
# Requirement already satisfied: numpy>=1.22 in c:\users\bolek\anaconda3\lib\site-packages (from geopandas>=0.14.3->keplergl) (1.26.4)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\users\bolek\anaconda3\lib\site-packages (from geopandas>=0.14.3->keplergl) (0.10.0)
# Requirement already satisfied: packaging in c:\users\bolek\anaconda3\lib\site-packages (from geopandas>=0.14.3->keplergl) (23.2)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\bolek\anaconda3\lib\site-packages (from geopandas>=0.14.3->keplergl) (3.7.0)
# Requirement already satisfied: comm>=0.1.3 in c:\users\bolek\anaconda3\lib\site-packages (from ipywidgets>=8.1.5->keplergl) (0.2.1)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\bolek\anaconda3\lib\site-packages (from ipywidgets>=8.1.5->keplergl) (8.25.0)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\bolek\anaconda3\lib\site-packages (from ipywidgets>=8.1.5->keplergl) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\users\bolek\anaconda3\lib\site-packages (from ipywidgets>=8.1.5->keplergl) (3.0.13)
# Requirement already satisfied: qtconsole in c:\users\bolek\anaconda3\lib\site-packages (from jupyter>=1.0.0->keplergl) (5.5.1)
# Requirement already satisfied: jupyter-console in c:\users\bolek\anaconda3\lib\site-packages (from jupyter>=1.0.0->keplergl) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\bolek\anaconda3\lib\site-packages (from jupyter>=1.0.0->keplergl) (7.10.0)
# Requirement already satisfied: ipykernel in c:\users\bolek\anaconda3\lib\site-packages (from jupyter>=1.0.0->keplergl) (6.28.0)
# Requirement already satisfied: deprecation in c:\users\bolek\anaconda3\lib\site-packages (from jupyter_packaging>=0.12.3->keplergl) (2.1.0)
# Requirement already satisfied: setuptools>=60.2.0 in c:\users\bolek\anaconda3\lib\site-packages (from jupyter_packaging>=0.12.3->keplergl) (74.0.0)
# Requirement already satisfied: tomlkit in c:\users\bolek\anaconda3\lib\site-packages (from jupyter_packaging>=0.12.3->keplergl) (0.11.1)
# Requirement already satisfied: wheel in c:\users\bolek\anaconda3\lib\site-packages (from jupyter_packaging>=0.12.3->keplergl) (0.44.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\bolek\anaconda3\lib\site-packages (from jupyterlab>=4.1.6->keplergl) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\bolek\anaconda3\lib\site-packages (from jupyterlab>=4.1.6->keplergl) (0.27.2)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\bolek\anaconda3\lib\site-packages (from jupyterlab>=4.1.6->keplergl) (3.1.4)
# Requirement already satisfied: jupyter-core in c:\users\bolek\anaconda3\lib\site-packages (from jupyterlab>=4.1.6->keplergl) (5.7.2)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\bolek\anaconda3\lib\site-packages (from jupyterlab>=4.1.6->keplergl) (2.2.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\bolek\anaconda3\lib\site-packages (from jupyterlab>=4.1.6->keplergl) (2.14.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\bolek\anaconda3\lib\site-packages (from jupyterlab>=4.1.6->keplergl) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in c:\users\bolek\anaconda3\lib\site-packages (from jupyterlab>=4.1.6->keplergl) (0.2.3)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\bolek\anaconda3\lib\site-packages (from jupyterlab>=4.1.6->keplergl) (6.4.1)
# Requirement already satisfied: anyio in c:\users\bolek\anaconda3\lib\site-packages (from httpx>=0.25.0->jupyterlab>=4.1.6->keplergl) (4.2.0)
# Requirement already satisfied: certifi in c:\users\bolek\anaconda3\lib\site-packages (from httpx>=0.25.0->jupyterlab>=4.1.6->keplergl) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in c:\users\bolek\anaconda3\lib\site-packages (from httpx>=0.25.0->jupyterlab>=4.1.6->keplergl) (1.0.5)
# Requirement already satisfied: idna in c:\users\bolek\anaconda3\lib\site-packages (from httpx>=0.25.0->jupyterlab>=4.1.6->keplergl) (3.7)
# Requirement already satisfied: sniffio in c:\users\bolek\anaconda3\lib\site-packages (from httpx>=0.25.0->jupyterlab>=4.1.6->keplergl) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\bolek\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab>=4.1.6->keplergl) (0.14.0)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\bolek\anaconda3\lib\site-packages (from ipykernel->jupyter>=1.0.0->keplergl) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\bolek\anaconda3\lib\site-packages (from ipykernel->jupyter>=1.0.0->keplergl) (8.6.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\bolek\anaconda3\lib\site-packages (from ipykernel->jupyter>=1.0.0->keplergl) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\bolek\anaconda3\lib\site-packages (from ipykernel->jupyter>=1.0.0->keplergl) (1.6.0)
# Requirement already satisfied: psutil in c:\users\bolek\anaconda3\lib\site-packages (from ipykernel->jupyter>=1.0.0->keplergl) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\bolek\anaconda3\lib\site-packages (from ipykernel->jupyter>=1.0.0->keplergl) (25.1.2)
# Requirement already satisfied: decorator in c:\users\bolek\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8.1.5->keplergl) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\bolek\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8.1.5->keplergl) (0.18.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\bolek\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8.1.5->keplergl) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\bolek\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8.1.5->keplergl) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\bolek\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8.1.5->keplergl) (0.2.0)
# Requirement already satisfied: colorama in c:\users\bolek\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8.1.5->keplergl) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\bolek\anaconda3\lib\site-packages (from jinja2>=3.0.3->jupyterlab>=4.1.6->keplergl) (2.1.3)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\bolek\anaconda3\lib\site-packages (from jupyter-core->jupyterlab>=4.1.6->keplergl) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\bolek\anaconda3\lib\site-packages (from jupyter-core->jupyterlab>=4.1.6->keplergl) (305.1)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\bolek\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (21.3.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\bolek\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\bolek\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (0.4.4)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\bolek\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (5.9.2)
# Requirement already satisfied: overrides>=5.0 in c:\users\bolek\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (7.4.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\bolek\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (0.14.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\bolek\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (2.0.10)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\bolek\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\bolek\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\bolek\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (1.8.0)
# Requirement already satisfied: babel>=2.10 in c:\users\bolek\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab>=4.1.6->keplergl) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\bolek\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab>=4.1.6->keplergl) (0.9.6)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\bolek\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab>=4.1.6->keplergl) (4.19.2)
# Requirement already satisfied: requests>=2.31 in c:\users\bolek\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab>=4.1.6->keplergl) (2.32.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\bolek\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->keplergl) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\bolek\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->keplergl) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\bolek\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->keplergl) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\bolek\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->keplergl) (0.1.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\bolek\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->keplergl) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\bolek\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->keplergl) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\bolek\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->keplergl) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\bolek\anaconda3\lib\site-packages (from nbconvert->jupyter>=1.0.0->keplergl) (1.2.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\bolek\anaconda3\lib\site-packages (from pandas->geoarrow-pandas>=0.1.1->keplergl) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\bolek\anaconda3\lib\site-packages (from pandas->geoarrow-pandas>=0.1.1->keplergl) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\bolek\anaconda3\lib\site-packages (from pandas->geoarrow-pandas>=0.1.1->keplergl) (2023.3)
# Requirement already satisfied: qtpy>=2.4.0 in c:\users\bolek\anaconda3\lib\site-packages (from qtconsole->jupyter>=1.0.0->keplergl) (2.4.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\bolek\anaconda3\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (21.2.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\bolek\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert->jupyter>=1.0.0->keplergl) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\bolek\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert->jupyter>=1.0.0->keplergl) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\bolek\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=8.1.5->keplergl) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\bolek\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab>=4.1.6->keplergl) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\bolek\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab>=4.1.6->keplergl) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\bolek\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab>=4.1.6->keplergl) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\bolek\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab>=4.1.6->keplergl) (0.10.6)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\bolek\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\bolek\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (6.0.1)
# Requirement already satisfied: rfc3339-validator in c:\users\bolek\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\bolek\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (0.1.1)
# Requirement already satisfied: fastjsonschema in c:\users\bolek\anaconda3\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (2.16.2)
# Requirement already satisfied: wcwidth in c:\users\bolek\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=8.1.5->keplergl) (0.2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\bolek\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab>=4.1.6->keplergl) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\bolek\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab>=4.1.6->keplergl) (2.2.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\bolek\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->jupyter>=1.0.0->keplergl) (2.5)
# Requirement already satisfied: executing in c:\users\bolek\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=8.1.5->keplergl) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\bolek\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=8.1.5->keplergl) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\bolek\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=8.1.5->keplergl) (0.2.2)
# Requirement already satisfied: fqdn in c:\users\bolek\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\bolek\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\bolek\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (2.1)
# Requirement already satisfied: uri-template in c:\users\bolek\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in c:\users\bolek\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (24.8.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\bolek\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\bolek\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\bolek\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.1.6->keplergl) (1.2.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install pydeck pandas h3 geopandas
# Out:
# Requirement already satisfied: pydeck in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (0.9.1)
# Requirement already satisfied: pandas in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (2.2.3)
# Requirement already satisfied: h3 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (4.1.2)
# Requirement already satisfied: geopandas in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (1.0.1)
# Requirement already satisfied: jinja2>=2.10.1 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from pydeck) (3.1.5)
# Requirement already satisfied: numpy>=1.16.4 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from pydeck) (2.2.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from geopandas) (0.10.0)
# Requirement already satisfied: packaging in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from geopandas) (24.2)
# Requirement already satisfied: pyproj>=3.3.0 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from geopandas) (3.7.0)
# Requirement already satisfied: shapely>=2.0.0 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from geopandas) (2.0.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from jinja2>=2.10.1->pydeck) (3.0.2)
# Requirement already satisfied: certifi in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from pyogrio>=0.7.2->geopandas) (2024.12.14)
# Requirement already satisfied: six>=1.5 in c:\dev\pandemic-spread-simulation\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import geopandas as gpd
from keplergl import KeplerGl
import pandas as pd

# %%
import json

def load_config(file_path):
    try:
        with open(file_path, 'r') as file:
            config = json.load(file)

        # Odczytanie zmiennych z pliku konfiguracyjnego
        transmission_rate = config["SEIR_parameters"]["transmission_rate"]
        incubation_rate = config["SEIR_parameters"]["incubation_rate"]
        recovery_rate = config["SEIR_parameters"]["recovery_rate"]

        vaccination_rate = config["vaccination"]["vaccination_rate"]
        vaccination_enabled = config["vaccination"]["vaccination_enabled"]

        lockdown_threshold = config["lockdown"]["lockdown_threshold"]
        lockdown_time = config["lockdown"]["lockdown_time"]

        flights_enabled = config["flights_enabled"]

        initial_infected_population_h3 = config["initial_infected_population_h3"]

        # Zwrócenie wszystkich ustawień jako słownik
        return {
            "transmission_rate": transmission_rate,
            "incubation_rate": incubation_rate,
            "recovery_rate": recovery_rate,
            "vaccination_rate": vaccination_rate,
            "vaccination_enabled": vaccination_enabled,
            "lockdown_threshold": lockdown_threshold,
            "lockdown_time": lockdown_time,
            "flights_enabled": flights_enabled,
            "initial_infected_population_h3": initial_infected_population_h3
        }
    except (FileNotFoundError, KeyError, json.JSONDecodeError) as e:
        print(f"Error loading configuration: {e}")
        return None

# %%
config_path = "config.json"
settings = load_config(config_path)

if settings:
    print("Ustawienia wczytane poprawnie:")
    for key, value in settings.items():
        print(f"{key}: {value}")
# Out:
# Ustawienia wczytane poprawnie:
# transmission_rate: 2
# incubation_rate: 1
# recovery_rate: 0.05
# vaccination_rate: 0.0002
# vaccination_enabled: False
# lockdown_threshold: 0.4
# lockdown_time: 30
# flights_enabled: True
# initial_infected_population_h3: {'846026bffffffff': 0.5, '841e25bffffffff': 0.5}

# %%
class Disease:
    def __init__(self):
        self.transmission_rate = settings.get("transmission_rate", 0.2)
        self.incubation_rate = settings.get("incubation_rate", 0.3)
        self.recovery_rate = settings.get("recovery_rate", 0.05)
        self.mortality_rate = 0

    def seir_rates(self):
        return self.transmission_rate, self.incubation_rate, self.recovery_rate, self.mortality_rate

# %%
import random


class PandemicSpreadSimulation:
    def __init__(self):
        self.vaccination_rate = settings.get("vaccination_rate", 0.01)
        self.vaccination_enabled = settings.get("vaccination_enabled", 0.2)
        self.lockdown_threshold = settings.get("lockdown_threshold", 0.2)
        self.lockdown_time = settings.get("lockdown_time", 30)
        self.flights_enabled = settings.get("flights_enabled", True)
        self.initial_infected_population_h3 = settings.get("initial_infected_population_h3", {})

        gdf = gpd.read_file('kontur_population_20231101_r4.gpkg')

        gdf = gdf[gdf['population'] > 50]

        # Upewnij się, że dane są w odpowiednim układzie współrzędnych (WGS84)
        gdf = gdf.to_crs(epsg=4326)

        # Dodaj pola SEIR do danych
        gdf['S'] = gdf['population']
        gdf['E'] = 0
        gdf['I'] = 0
        gdf['R'] = 0
        gdf['V'] = 0
        gdf['airport'] = False
        gdf['masks'] = False
        gdf['lockdown'] = 0
        gdf['vaccinations'] = False

        number_of_airports = 2000
        airport_indices = gdf.sample(n=number_of_airports, random_state=42).index
        gdf.loc[airport_indices, 'airport'] = True

        for hex_id, infection_progress in self.initial_infected_population_h3.items():
            target_hex = gdf[gdf['h3'] == hex_id]
            if not target_hex.empty:
                initial_infection = int(
                    target_hex['population'].values[0] * infection_progress
                )
                gdf.loc[gdf['h3'] == hex_id, 'I'] = initial_infection
                gdf.loc[gdf['h3'] == hex_id, 'S'] -= initial_infection
            else:
                print(f"No target hex found for h3 id {hex_id}")

        self.gdf = gdf
        self.disease = Disease()

    def infect_neighbors(self):
        for index, row in self.gdf.iterrows():
            infected = row['I']
            if infected == 0:
                continue

            neighbors = self.gdf[self.gdf.geometry.touches(row.geometry)]

            for neighbor_index, neighbor in neighbors.iterrows():
                neighbor_S = neighbor['S']

                transmission_probability = 1 - ((1 - infected / row['population']) ** 5)

                is_transmitted = random.random() < transmission_probability
                if is_transmitted:
                    new_exposed = random.randint(1, 10)  # Zakładamy losową liczbę nowych narażonych
                    actual_exposed = min(new_exposed, neighbor_S)  # Nie więcej niż dostępni w S

                    self.gdf.at[neighbor_index, 'S'] -= actual_exposed
                    self.gdf.at[neighbor_index, 'E'] += actual_exposed

        print("Neighbor infections processed.")

    # update simulation state by a day
    def update_simulation(self):
        self.infect_neighbors()

        if self.flights_enabled:
            self.simulate_flight()

        transmission_rate, incubation_rate, recovery_rate, mortality_rate = self.disease.seir_rates()

        for index, row in self.gdf.iterrows():
            S = row['S']
            E = row['E']
            I = row['I']
            R = row['R']
            population = row['population']
            lockdown_days = row['lockdown']

            # Decrease lockdown days if still active
            if lockdown_days > 0:
                self.gdf.loc[index, 'lockdown'] = lockdown_days - 1

            # Calculate new exposed, infected, recovered, and dead
            new_exposed = int(transmission_rate * S * I / population)
            new_infected = int(incubation_rate * E)
            new_recovered = int(recovery_rate * I)
            new_dead = int(mortality_rate * I)

            # Update SEIR values (ensuring no negative values)
            new_S = max(S - new_exposed, 0)
            new_E = max(E + new_exposed - new_infected, 0)
            new_I = max(I + new_infected - new_recovered - new_dead, 0)
            new_R = max(R + new_recovered, 0)

            if self.vaccination_enabled:
                new_V = new_S * self.vaccination_rate
                new_S = max(S - new_V, 0)
                self.gdf.loc[index, 'V'] = new_V

            # Update the values in the geodataframe using loc[]
            self.gdf.loc[index, 'S'] = new_S
            self.gdf.loc[index, 'E'] = new_E
            self.gdf.loc[index, 'I'] = new_I
            self.gdf.loc[index, 'R'] = new_R

    def simulate_flight(self):
        airports = self.gdf[(self.gdf['lockdown'] == False) & (self.gdf['airport'] == True)]

        for _, origin in airports.iterrows():
            if origin['I'] < 200000:
                continue

            sampled_airports = airports.sample(1)
            destination = sampled_airports.iloc[0]

            passengers = random.randint(100, 300)

            infected_probability = 1 - (1 - origin['I'] / origin['population'])

            print(infected_probability)

            is_infected = random.random() < infected_probability

            if is_infected:
                destination_S = self.gdf.at[destination.name, 'S']
                new_exposed = min(passengers, destination_S)  # Nie więcej niż S

                self.gdf.at[destination.name, 'S'] -= new_exposed
                self.gdf.at[destination.name, 'E'] += new_exposed

                print(f"Flight from {origin['h3']} to {destination['h3']}")
                print(f"Passengers: {passengers}")

# %%
import os
from datetime import datetime

simulation = PandemicSpreadSimulation()

current_time = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
folder_name = f"pandemic_spread_{current_time}"
os.makedirs(folder_name, exist_ok=True)

initial_state = simulation.gdf.copy()
initial_state.to_file(os.path.join(folder_name, "day_0.geojson"), driver="GeoJSON")

num_days = 20

print(f"\nRozpoczynam symulację dla {num_days - 1} kolejnych dni...")
for day in range(num_days - 1):
    print(f"\nDzień {day + 1}:")
    simulation.update_simulation()
    current_state = simulation.gdf.copy()
    print(f"- Liczba zarażonych (suma I): {current_state['I'].sum()}")
    print(f"- Liczba podatnych (suma S): {current_state['S'].sum()}")

    current_state.to_file(os.path.join(folder_name, f"day_{day + 1}.geojson"), driver="GeoJSON")

print("Koniec symulacji")
# Out:
# Rozpoczynam symulację dla 19 kolejnych dni...
#
# Dzień 1:
# Neighbor infections processed.
# - Liczba zarażonych (suma I): 583927
# - Liczba podatnych (suma S): 8030548633.0
#
# Dzień 2:
# Neighbor infections processed.
# - Liczba zarażonych (suma I): 1169393
# - Liczba podatnych (suma S): 8030548516.0
#
# Dzień 3:
# Neighbor infections processed.
# - Liczba zarażonych (suma I): 1111037
# - Liczba podatnych (suma S): 8030548319.0
#
# Dzień 4:
# Neighbor infections processed.
# - Liczba zarażonych (suma I): 1055706
# - Liczba podatnych (suma S): 8030547889.0
#
# Dzień 5:
# Neighbor infections processed.
# - Liczba zarażonych (suma I): 1003346
# - Liczba podatnych (suma S): 8030547052.0
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# File pyogrio\\_io.pyx:1947, in pyogrio._io.ogr_create()
#
# File pyogrio\\_err.pyx:183, in pyogrio._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: Failed to create GeoJSON datasource: pandemic_spread_2025-01-17_15-05-36\day_5.geojson: pandemic_spread_2025-01-17_15-05-36\day_5.geojson: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DataSourceError                           Traceback (most recent call last)
# Cell In[15], line 23
#      20     print(f"- Liczba zarażonych (suma I): {current_state['I'].sum()}")
#      21     print(f"- Liczba podatnych (suma S): {current_state['S'].sum()}")
# ---> 23     current_state.to_file(os.path.join(folder_name, f"day_{day + 1}.geojson"), driver="GeoJSON")
#      25 print("Koniec symulacji")
#
# File C:\Dev\Pandemic-Spread-Simulation\.venv\Lib\site-packages\geopandas\geodataframe.py:1536, in GeoDataFrame.to_file(self, filename, driver, schema, index, **kwargs)
#    1441 """Write the ``GeoDataFrame`` to a file.
#    1442
#    1443 By default, an ESRI shapefile is written, but any OGR data source
#    (...)
#    1532
#    1533 """
#    1534 from geopandas.io.file import _to_file
# -> 1536 _to_file(self, filename, driver, schema, index, **kwargs)
#
# File C:\Dev\Pandemic-Spread-Simulation\.venv\Lib\site-packages\geopandas\io\file.py:686, in _to_file(df, filename, driver, schema, index, mode, crs, engine, metadata, **kwargs)
#     683     raise ValueError(f"'mode' should be one of 'w' or 'a', got '{mode}' instead")
#     685 if engine == "pyogrio":
# --> 686     _to_file_pyogrio(df, filename, driver, schema, crs, mode, metadata, **kwargs)
#     687 elif engine == "fiona":
#     688     _to_file_fiona(df, filename, driver, schema, crs, mode, metadata, **kwargs)
#
# File C:\Dev\Pandemic-Spread-Simulation\.venv\Lib\site-packages\geopandas\io\file.py:748, in _to_file_pyogrio(df, filename, driver, schema, crs, mode, metadata, **kwargs)
#     745 if not df.columns.is_unique:
#     746     raise ValueError("GeoDataFrame cannot contain duplicated column names.")
# --> 748 pyogrio.write_dataframe(df, filename, driver=driver, metadata=metadata, **kwargs)
#
# File C:\Dev\Pandemic-Spread-Simulation\.venv\Lib\site-packages\pyogrio\geopandas.py:662, in write_dataframe(df, path, layer, driver, encoding, geometry_type, promote_to_multi, nan_as_null, append, use_arrow, dataset_metadata, layer_metadata, metadata, dataset_options, layer_options, **kwargs)
#     659 if geometry_column is not None:
#     660     geometry = to_wkb(geometry.values)
# --> 662 write(
#     663     path,
#     664     layer=layer,
#     665     driver=driver,
#     666     geometry=geometry,
#     667     field_data=field_data,
#     668     field_mask=field_mask,
#     669     fields=fields,
#     670     crs=crs,
#     671     geometry_type=geometry_type,
#     672     encoding=encoding,
#     673     promote_to_multi=promote_to_multi,
#     674     nan_as_null=nan_as_null,
#     675     append=append,
#     676     dataset_metadata=dataset_metadata,
#     677     layer_metadata=layer_metadata,
#     678     metadata=metadata,
#     679     dataset_options=dataset_options,
#     680     layer_options=layer_options,
#     681     gdal_tz_offsets=gdal_tz_offsets,
#     682     **kwargs,
#     683 )
#
# File C:\Dev\Pandemic-Spread-Simulation\.venv\Lib\site-packages\pyogrio\raw.py:723, in write(path, geometry, field_data, fields, field_mask, layer, driver, geometry_type, crs, encoding, promote_to_multi, nan_as_null, append, dataset_metadata, layer_metadata, metadata, dataset_options, layer_options, gdal_tz_offsets, **kwargs)
#     718 # preprocess kwargs and split in dataset and layer creation options
#     719 dataset_kwargs, layer_kwargs = _preprocess_options_kwargs(
#     720     driver, dataset_options, layer_options, kwargs
#     721 )
# --> 723 ogr_write(
#     724     path,
#     725     layer=layer,
#     726     driver=driver,
#     727     geometry=geometry,
#     728     geometry_type=geometry_type,
#     729     field_data=field_data,
#     730     field_mask=field_mask,
#     731     fields=fields,
#     732     crs=crs,
#     733     encoding=encoding,
#     734     promote_to_multi=promote_to_multi,
#     735     nan_as_null=nan_as_null,
#     736     append=append,
#     737     dataset_metadata=dataset_metadata,
#     738     layer_metadata=layer_metadata,
#     739     dataset_kwargs=dataset_kwargs,
#     740     layer_kwargs=layer_kwargs,
#     741     gdal_tz_offsets=gdal_tz_offsets,
#     742 )
#
# File pyogrio\\_io.pyx:2307, in pyogrio._io.ogr_write()
#
# File pyogrio\\_io.pyx:2135, in pyogrio._io.create_ogr_dataset_layer()
#
# File pyogrio\\_io.pyx:1956, in pyogrio._io.ogr_create()
#
# DataSourceError: Failed to create GeoJSON datasource: pandemic_spread_2025-01-17_15-05-36\day_5.geojson: pandemic_spread_2025-01-17_15-05-36\day_5.geojson: No such file or directory

# %%
def create_map_with_simulation(simulation_states, filename='pandemic_simulation.html'):
    """
    Tworzy mapę z warstwami dla każdego dnia symulacji
    """
    print("Rozpoczynam tworzenie mapy...")

    try:
        # Wczytaj dane granic państw i miast
        print("Wczytuję dane granic państw...")
        countries = gpd.read_file("ne_110m_admin_0_countries.shp")
        countries.set_crs(epsg=4326, inplace=True)
        print("Wczytuję dane miast...")
        cities = gpd.read_file("ne_110m_populated_places.shp")
        cities.set_crs(epsg=4326, inplace=True)
        print("Dane bazowe wczytane pomyślnie")

        # Lista do przechowywania wszystkich stanów symulacji
        # simulation_states = []

        # Zapisz stan początkowy
        # print("Zapisuję stan początkowy symulacji...")
        initial_state = simulation_states[0]
        print(f"Stan początkowy - liczba rekordów: {len(initial_state)}")
        print(f"Kolumny w danych: {initial_state.columns.tolist()}")
        #simulation_states.append(initial_state)



        # Stwórz mapę
        print("\nTworzę obiekt mapy...")
        map_1 = KeplerGl(height=800)
        
        # Dodaj podstawowe dane
        print("Dodaję dane bazowe do mapy...")
        map_1.add_data(data=countries, name="countries")
        map_1.add_data(data=cities, name="cities")

        # Dodaj dane dla każdego dnia
        print("\nDodaję dane dla poszczególnych dni...")
        for day, state in enumerate(simulation_states):
            print(f"Dodaję dzień {day}...")
            print(f"- Kształt danych: {state.shape}")
            print(f"- Kolumna h3 obecna: {'h3' in state.columns}")
            print(f"- Kolumna I obecna: {'I' in state.columns}")
            map_1.add_data(data=state, name=f'pandemic_day_{day}')

        print("\nPrzygotowuję konfigurację warstw...")
        # Przygotuj warstwy dla każdego dnia
        layers = [
            # Warstwa granic państw
            {
                "id": "country_borders",
                "type": "geojson",
                "config": {
                    "dataId": "countries",
                    "label": "Countries",
                    "color": [200, 200, 200],
                    "columns": {"geojson": "geometry"},
                    "isVisible": True,
                    "visConfig": {
                        "opacity": 0.3,
                        "thickness": 1
                    }
                }
            },
            # Warstwa miast
            {
                "id": "cities_layer",
                "type": "geojson",
                "config": {
                    "dataId": "cities",
                    "label": "Cities",
                    "color": [255, 0, 0],
                    "columns": {"geojson": "geometry"},
                    "isVisible": True
                }
            }
        ]

        # Dodaj warstwę dla każdego dnia symulacji
        for day in range(len(simulation_states)):
            print(f"Dodaję konfigurację dla dnia {day}...")
            layer = {
                "id": f"infected_layer_day_{day}",
                "type": "hexagonId",
                "config": {
                    "dataId": f"pandemic_day_{day}",
                    "label": f"Infected Population - Day {day}",
                    "columns": {
                        "hex_id": "h3"
                    },
                    "isVisible": day == 0,
                    "visConfig": {
                                "coverage": 1,
                                "enable3d": True,
                                "sizeRange": [0, 500],
                                "coverageRange": [0, 1],
                                "elevationScale": 5,
                                "heightRange": [0, 500],
                                "colorScaleType": "linear",
                                "strokeColor": [255, 255, 255],
                                "strokeColorRange": {
                                    "name": "Global Warming",
                                    "type": "sequential",
                                    "category": "Uber",
                                    "colors": ["#FFF5F0", "#FEE0D2", "#FCBBA1", "#FC9272", "#FB6A4A", "#EF3B2C", "#CB181D", "#A50F15", "#67000D"]
                                }
                            }
                        },
                        "visualChannels": {
                            "colorField": {
                                "name": "I",
                                "type": "real",
                                "scale": "linear",
                                "domain": [0, 530900]  # Min i max wartości
                            },
                            "colorScale": "quantize",
                            "heightField": {
                                "name": "I",
                                "type": "real",
                                "scale": "linear",
                                "domain": [0, 530900]  # Min i max wartości
                            },
                            "sizeField": {
                                "name": "population",
                                "type": "real"
                            },
                            "sizeScale": "linear",
                            "heightScale": "linear"
                        }
            }
            
            
            layers.append(layer)

        # Konfiguracja mapy
        print("Tworzę końcową konfigurację mapy...")
        config = {
            "version": "v1",
            "config": {
                "visState": {
                    "filters": [],
                    "layers": layers
                },
                "mapState": {
                    "bearing": 0,
                    "latitude": 50,
                    "longitude": 20,
                    "pitch": 45,
                    "zoom": 4,
                    "dragRotate": True
                },
                "mapStyle": {
                    "styleType": "dark",
                    "topLayerGroups": {},
                    "visibleLayerGroups": {
                        "label": True,
                        "road": True,
                        "border": True,
                        "building": True,
                        "water": True,
                        "land": True
                    }
                }
            }
        }

        print("\nStosuje konfigurację do mapy...")
        map_1.config = config

        print(f"\nZapisuję mapę do pliku {filename}...")
        map_1.save_to_html(file_name=filename)
        
        print("\nMapa została utworzona pomyślnie!")
        return map_1

    except Exception as e:
        print(f"\nWYSTĄPIŁ BŁĄD: {str(e)}")
        import traceback
        print("\nSzczegóły błędu:")
        print(traceback.format_exc())
        raise

# Przykład użycia:
try:
    print("\nUruchamiam tworzenie mapy z symulacją...")

    directory = 'pandemic_spread_2025-01-16_20-26-32'
    geojson_files = [f for f in os.listdir(directory) if f.endswith('.geojson')]

    for geojson_file in geojson_files:
        state_name = os.path.splitext(geojson_file)[0]
        state_path = os.path.join(directory, geojson_file)
        state_data = gpd.read_file(state_path)
        infected_count = state_data['I'].sum() if 'I' in state_data else 0
        print(f"- Plik: {geojson_file}, Liczba zarażonych: {infected_count}")
        html_filename = os.path.join(directory, f"{state_name}.html")
        create_map_with_simulation([state_data], html_filename)
except Exception as e:
    print(f"\nBłąd podczas wykonywania głównego kodu: {str(e)}")
# Out:
# Uruchamiam tworzenie mapy z symulacją...
# - Plik: day_0.geojson, Liczba zarażonych: 614616
# Rozpoczynam tworzenie mapy...
# Wczytuję dane granic państw...
# Wczytuję dane miast...
# Dane bazowe wczytane pomyślnie
# Stan początkowy - liczba rekordów: 60790
# Kolumny w danych: ['h3', 'population', 'S', 'E', 'I', 'R', 'V', 'airport', 'masks', 'lockdown', 'vaccinations', 'geometry']
#
# Tworzę obiekt mapy...
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# Dodaję dane bazowe do mapy...
#
# Dodaję dane dla poszczególnych dni...
# Dodaję dzień 0...
# - Kształt danych: (60790, 12)
# - Kolumna h3 obecna: True
# - Kolumna I obecna: True
#
# Przygotowuję konfigurację warstw...
# Dodaję konfigurację dla dnia 0...
# Tworzę końcową konfigurację mapy...
#
# Stosuje konfigurację do mapy...
#
# Zapisuję mapę do pliku pandemic_spread_2025-01-16_20-26-32\day_0.html...
# Map saved to pandemic_spread_2025-01-16_20-26-32\day_0.html!
#
# Mapa została utworzona pomyślnie!
# - Plik: day_1.geojson, Liczba zarażonych: 584217
# Rozpoczynam tworzenie mapy...
# Wczytuję dane granic państw...
# Wczytuję dane miast...
# Dane bazowe wczytane pomyślnie
# Stan początkowy - liczba rekordów: 60790
# Kolumny w danych: ['h3', 'population', 'S', 'E', 'I', 'R', 'V', 'airport', 'masks', 'lockdown', 'vaccinations', 'geometry']
#
# Tworzę obiekt mapy...
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# Dodaję dane bazowe do mapy...
#
# Dodaję dane dla poszczególnych dni...
# Dodaję dzień 0...
# - Kształt danych: (60790, 12)
# - Kolumna h3 obecna: True
# - Kolumna I obecna: True
#
# Przygotowuję konfigurację warstw...
# Dodaję konfigurację dla dnia 0...
# Tworzę końcową konfigurację mapy...
#
# Stosuje konfigurację do mapy...
#
# Zapisuję mapę do pliku pandemic_spread_2025-01-16_20-26-32\day_1.html...
# Map saved to pandemic_spread_2025-01-16_20-26-32\day_1.html!
#
# Mapa została utworzona pomyślnie!
# - Plik: day_10.geojson, Liczba zarażonych: 830881
# Rozpoczynam tworzenie mapy...
# Wczytuję dane granic państw...
# Wczytuję dane miast...
# Dane bazowe wczytane pomyślnie
# Stan początkowy - liczba rekordów: 60790
# Kolumny w danych: ['h3', 'population', 'S', 'E', 'I', 'R', 'V', 'airport', 'masks', 'lockdown', 'vaccinations', 'geometry']
#
# Tworzę obiekt mapy...
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# Dodaję dane bazowe do mapy...
#
# Dodaję dane dla poszczególnych dni...
# Dodaję dzień 0...
# - Kształt danych: (60790, 12)
# - Kolumna h3 obecna: True
# - Kolumna I obecna: True
#
# Przygotowuję konfigurację warstw...
# Dodaję konfigurację dla dnia 0...
# Tworzę końcową konfigurację mapy...
#
# Stosuje konfigurację do mapy...
#
# Zapisuję mapę do pliku pandemic_spread_2025-01-16_20-26-32\day_10.html...
# Map saved to pandemic_spread_2025-01-16_20-26-32\day_10.html!
#
# Mapa została utworzona pomyślnie!
# - Plik: day_11.geojson, Liczba zarażonych: 835484
# Rozpoczynam tworzenie mapy...
# Wczytuję dane granic państw...
# Wczytuję dane miast...
# Dane bazowe wczytane pomyślnie
# Stan początkowy - liczba rekordów: 60790
# Kolumny w danych: ['h3', 'population', 'S', 'E', 'I', 'R', 'V', 'airport', 'masks', 'lockdown', 'vaccinations', 'geometry']
#
# Tworzę obiekt mapy...
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# Dodaję dane bazowe do mapy...
#
# Dodaję dane dla poszczególnych dni...
# Dodaję dzień 0...
# - Kształt danych: (60790, 12)
# - Kolumna h3 obecna: True
# - Kolumna I obecna: True
#
# Przygotowuję konfigurację warstw...
# Dodaję konfigurację dla dnia 0...
# Tworzę końcową konfigurację mapy...
#
# Stosuje konfigurację do mapy...
#
# Zapisuję mapę do pliku pandemic_spread_2025-01-16_20-26-32\day_11.html...
# Map saved to pandemic_spread_2025-01-16_20-26-32\day_11.html!
#
# Mapa została utworzona pomyślnie!
# - Plik: day_12.geojson, Liczba zarażonych: 878265
# Rozpoczynam tworzenie mapy...
# Wczytuję dane granic państw...
# Wczytuję dane miast...
# Dane bazowe wczytane pomyślnie
# Stan początkowy - liczba rekordów: 60790
# Kolumny w danych: ['h3', 'population', 'S', 'E', 'I', 'R', 'V', 'airport', 'masks', 'lockdown', 'vaccinations', 'geometry']
#
# Tworzę obiekt mapy...
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# Dodaję dane bazowe do mapy...
#
# Dodaję dane dla poszczególnych dni...
# Dodaję dzień 0...
# - Kształt danych: (60790, 12)
# - Kolumna h3 obecna: True
# - Kolumna I obecna: True
#
# Przygotowuję konfigurację warstw...
# Dodaję konfigurację dla dnia 0...
# Tworzę końcową konfigurację mapy...
#
# Stosuje konfigurację do mapy...
#
# Zapisuję mapę do pliku pandemic_spread_2025-01-16_20-26-32\day_12.html...
# Map saved to pandemic_spread_2025-01-16_20-26-32\day_12.html!
#
# Mapa została utworzona pomyślnie!
# - Plik: day_13.geojson, Liczba zarażonych: 983744
# Rozpoczynam tworzenie mapy...
# Wczytuję dane granic państw...
# Wczytuję dane miast...
# Dane bazowe wczytane pomyślnie
# Stan początkowy - liczba rekordów: 60790
# Kolumny w danych: ['h3', 'population', 'S', 'E', 'I', 'R', 'V', 'airport', 'masks', 'lockdown', 'vaccinations', 'geometry']
#
# Tworzę obiekt mapy...
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# Dodaję dane bazowe do mapy...
#
# Dodaję dane dla poszczególnych dni...
# Dodaję dzień 0...
# - Kształt danych: (60790, 12)
# - Kolumna h3 obecna: True
# - Kolumna I obecna: True
#
# Przygotowuję konfigurację warstw...
# Dodaję konfigurację dla dnia 0...
# Tworzę końcową konfigurację mapy...
#
# Stosuje konfigurację do mapy...
#
# Zapisuję mapę do pliku pandemic_spread_2025-01-16_20-26-32\day_13.html...
# Map saved to pandemic_spread_2025-01-16_20-26-32\day_13.html!
#
# Mapa została utworzona pomyślnie!
# - Plik: day_14.geojson, Liczba zarażonych: 1190345
# Rozpoczynam tworzenie mapy...
# Wczytuję dane granic państw...
# Wczytuję dane miast...
# Dane bazowe wczytane pomyślnie
# Stan początkowy - liczba rekordów: 60790
# Kolumny w danych: ['h3', 'population', 'S', 'E', 'I', 'R', 'V', 'airport', 'masks', 'lockdown', 'vaccinations', 'geometry']
#
# Tworzę obiekt mapy...
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# Dodaję dane bazowe do mapy...
#
# Dodaję dane dla poszczególnych dni...
# Dodaję dzień 0...
# - Kształt danych: (60790, 12)
# - Kolumna h3 obecna: True
# - Kolumna I obecna: True
#
# Przygotowuję konfigurację warstw...
# Dodaję konfigurację dla dnia 0...
# Tworzę końcową konfigurację mapy...
#
# Stosuje konfigurację do mapy...
#
# Zapisuję mapę do pliku pandemic_spread_2025-01-16_20-26-32\day_14.html...
# Map saved to pandemic_spread_2025-01-16_20-26-32\day_14.html!
#
# Mapa została utworzona pomyślnie!
# - Plik: day_15.geojson, Liczba zarażonych: 1548162
# Rozpoczynam tworzenie mapy...
# Wczytuję dane granic państw...
# Wczytuję dane miast...
# Dane bazowe wczytane pomyślnie
# Stan początkowy - liczba rekordów: 60790
# Kolumny w danych: ['h3', 'population', 'S', 'E', 'I', 'R', 'V', 'airport', 'masks', 'lockdown', 'vaccinations', 'geometry']
#
# Tworzę obiekt mapy...
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# Dodaję dane bazowe do mapy...
#
# Dodaję dane dla poszczególnych dni...
# Dodaję dzień 0...
# - Kształt danych: (60790, 12)
# - Kolumna h3 obecna: True
# - Kolumna I obecna: True
#
# Przygotowuję konfigurację warstw...
# Dodaję konfigurację dla dnia 0...
# Tworzę końcową konfigurację mapy...
#
# Stosuje konfigurację do mapy...
#
# Zapisuję mapę do pliku pandemic_spread_2025-01-16_20-26-32\day_15.html...
# Map saved to pandemic_spread_2025-01-16_20-26-32\day_15.html!
#
# Mapa została utworzona pomyślnie!
# - Plik: day_16.geojson, Liczba zarażonych: 2120709
# Rozpoczynam tworzenie mapy...
# Wczytuję dane granic państw...
# Wczytuję dane miast...
# Dane bazowe wczytane pomyślnie
# Stan początkowy - liczba rekordów: 60790
# Kolumny w danych: ['h3', 'population', 'S', 'E', 'I', 'R', 'V', 'airport', 'masks', 'lockdown', 'vaccinations', 'geometry']
#
# Tworzę obiekt mapy...
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# Dodaję dane bazowe do mapy...
#
# Dodaję dane dla poszczególnych dni...
# Dodaję dzień 0...
# - Kształt danych: (60790, 12)
# - Kolumna h3 obecna: True
# - Kolumna I obecna: True
#
# Przygotowuję konfigurację warstw...
# Dodaję konfigurację dla dnia 0...
# Tworzę końcową konfigurację mapy...
#
# Stosuje konfigurację do mapy...
#
# Zapisuję mapę do pliku pandemic_spread_2025-01-16_20-26-32\day_16.html...
# Map saved to pandemic_spread_2025-01-16_20-26-32\day_16.html!
#
# Mapa została utworzona pomyślnie!
# - Plik: day_17.geojson, Liczba zarażonych: 2930465
# Rozpoczynam tworzenie mapy...
# Wczytuję dane granic państw...
# Wczytuję dane miast...
# Dane bazowe wczytane pomyślnie
# Stan początkowy - liczba rekordów: 60790
# Kolumny w danych: ['h3', 'population', 'S', 'E', 'I', 'R', 'V', 'airport', 'masks', 'lockdown', 'vaccinations', 'geometry']
#
# Tworzę obiekt mapy...
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# Dodaję dane bazowe do mapy...
#
# Dodaję dane dla poszczególnych dni...
# Dodaję dzień 0...
# - Kształt danych: (60790, 12)
# - Kolumna h3 obecna: True
# - Kolumna I obecna: True
#
# Przygotowuję konfigurację warstw...
# Dodaję konfigurację dla dnia 0...
# Tworzę końcową konfigurację mapy...
#
# Stosuje konfigurację do mapy...
#
# Zapisuję mapę do pliku pandemic_spread_2025-01-16_20-26-32\day_17.html...
# Map saved to pandemic_spread_2025-01-16_20-26-32\day_17.html!
#
# Mapa została utworzona pomyślnie!
# - Plik: day_18.geojson, Liczba zarażonych: 3844329
# Rozpoczynam tworzenie mapy...
# Wczytuję dane granic państw...
# Wczytuję dane miast...
# Dane bazowe wczytane pomyślnie
# Stan początkowy - liczba rekordów: 60790
# Kolumny w danych: ['h3', 'population', 'S', 'E', 'I', 'R', 'V', 'airport', 'masks', 'lockdown', 'vaccinations', 'geometry']
#
# Tworzę obiekt mapy...
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# Dodaję dane bazowe do mapy...
#
# Dodaję dane dla poszczególnych dni...
# Dodaję dzień 0...
# - Kształt danych: (60790, 12)
# - Kolumna h3 obecna: True
# - Kolumna I obecna: True
#
# Przygotowuję konfigurację warstw...
# Dodaję konfigurację dla dnia 0...
# Tworzę końcową konfigurację mapy...
#
# Stosuje konfigurację do mapy...
#
# Zapisuję mapę do pliku pandemic_spread_2025-01-16_20-26-32\day_18.html...
# Map saved to pandemic_spread_2025-01-16_20-26-32\day_18.html!
#
# Mapa została utworzona pomyślnie!
# - Plik: day_19.geojson, Liczba zarażonych: 4751485
# Rozpoczynam tworzenie mapy...
# Wczytuję dane granic państw...
# Wczytuję dane miast...
# Dane bazowe wczytane pomyślnie
# Stan początkowy - liczba rekordów: 60790
# Kolumny w danych: ['h3', 'population', 'S', 'E', 'I', 'R', 'V', 'airport', 'masks', 'lockdown', 'vaccinations', 'geometry']
#
# Tworzę obiekt mapy...
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# Dodaję dane bazowe do mapy...
#
# Dodaję dane dla poszczególnych dni...
# Dodaję dzień 0...
# - Kształt danych: (60790, 12)
# - Kolumna h3 obecna: True
# - Kolumna I obecna: True
#
# Przygotowuję konfigurację warstw...
# Dodaję konfigurację dla dnia 0...
# Tworzę końcową konfigurację mapy...
#
# Stosuje konfigurację do mapy...
#
# Zapisuję mapę do pliku pandemic_spread_2025-01-16_20-26-32\day_19.html...
# Map saved to pandemic_spread_2025-01-16_20-26-32\day_19.html!
#
# Mapa została utworzona pomyślnie!
# - Plik: day_2.geojson, Liczba zarażonych: 1169939
# Rozpoczynam tworzenie mapy...
# Wczytuję dane granic państw...
# Wczytuję dane miast...
# Dane bazowe wczytane pomyślnie
# Stan początkowy - liczba rekordów: 60790
# Kolumny w danych: ['h3', 'population', 'S', 'E', 'I', 'R', 'V', 'airport', 'masks', 'lockdown', 'vaccinations', 'geometry']
#
# Tworzę obiekt mapy...
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# Dodaję dane bazowe do mapy...
#
# Dodaję dane dla poszczególnych dni...
# Dodaję dzień 0...
# - Kształt danych: (60790, 12)
# - Kolumna h3 obecna: True
# - Kolumna I obecna: True
#
# Przygotowuję konfigurację warstw...
# Dodaję konfigurację dla dnia 0...
# Tworzę końcową konfigurację mapy...
#
# Stosuje konfigurację do mapy...
#
# Zapisuję mapę do pliku pandemic_spread_2025-01-16_20-26-32\day_2.html...
# Map saved to pandemic_spread_2025-01-16_20-26-32\day_2.html!
#
# Mapa została utworzona pomyślnie!
# - Plik: day_3.geojson, Liczba zarażonych: 1112264
# Rozpoczynam tworzenie mapy...
# Wczytuję dane granic państw...
# Wczytuję dane miast...
# Dane bazowe wczytane pomyślnie
# Stan początkowy - liczba rekordów: 60790
# Kolumny w danych: ['h3', 'population', 'S', 'E', 'I', 'R', 'V', 'airport', 'masks', 'lockdown', 'vaccinations', 'geometry']
#
# Tworzę obiekt mapy...
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# Dodaję dane bazowe do mapy...
#
# Dodaję dane dla poszczególnych dni...
# Dodaję dzień 0...
# - Kształt danych: (60790, 12)
# - Kolumna h3 obecna: True
# - Kolumna I obecna: True
#
# Przygotowuję konfigurację warstw...
# Dodaję konfigurację dla dnia 0...
# Tworzę końcową konfigurację mapy...
#
# Stosuje konfigurację do mapy...
#
# Zapisuję mapę do pliku pandemic_spread_2025-01-16_20-26-32\day_3.html...
# Map saved to pandemic_spread_2025-01-16_20-26-32\day_3.html!
#
# Mapa została utworzona pomyślnie!
# - Plik: day_4.geojson, Liczba zarażonych: 1057912
# Rozpoczynam tworzenie mapy...
# Wczytuję dane granic państw...
# Wczytuję dane miast...
# Dane bazowe wczytane pomyślnie
# Stan początkowy - liczba rekordów: 60790
# Kolumny w danych: ['h3', 'population', 'S', 'E', 'I', 'R', 'V', 'airport', 'masks', 'lockdown', 'vaccinations', 'geometry']
#
# Tworzę obiekt mapy...
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# Dodaję dane bazowe do mapy...
#
# Dodaję dane dla poszczególnych dni...
# Dodaję dzień 0...
# - Kształt danych: (60790, 12)
# - Kolumna h3 obecna: True
# - Kolumna I obecna: True
#
# Przygotowuję konfigurację warstw...
# Dodaję konfigurację dla dnia 0...
# Tworzę końcową konfigurację mapy...
#
# Stosuje konfigurację do mapy...
#
# Zapisuję mapę do pliku pandemic_spread_2025-01-16_20-26-32\day_4.html...
# Map saved to pandemic_spread_2025-01-16_20-26-32\day_4.html!
#
# Mapa została utworzona pomyślnie!
# - Plik: day_5.geojson, Liczba zarażonych: 1007210
# Rozpoczynam tworzenie mapy...
# Wczytuję dane granic państw...
# Wczytuję dane miast...
# Dane bazowe wczytane pomyślnie
# Stan początkowy - liczba rekordów: 60790
# Kolumny w danych: ['h3', 'population', 'S', 'E', 'I', 'R', 'V', 'airport', 'masks', 'lockdown', 'vaccinations', 'geometry']
#
# Tworzę obiekt mapy...
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# Dodaję dane bazowe do mapy...
#
# Dodaję dane dla poszczególnych dni...
# Dodaję dzień 0...
# - Kształt danych: (60790, 12)
# - Kolumna h3 obecna: True
# - Kolumna I obecna: True
#
# Przygotowuję konfigurację warstw...
# Dodaję konfigurację dla dnia 0...
# Tworzę końcową konfigurację mapy...
#
# Stosuje konfigurację do mapy...
#
# Zapisuję mapę do pliku pandemic_spread_2025-01-16_20-26-32\day_5.html...
# Map saved to pandemic_spread_2025-01-16_20-26-32\day_5.html!
#
# Mapa została utworzona pomyślnie!
# - Plik: day_6.geojson, Liczba zarażonych: 960109
# Rozpoczynam tworzenie mapy...
# Wczytuję dane granic państw...
# Wczytuję dane miast...
# Dane bazowe wczytane pomyślnie
# Stan początkowy - liczba rekordów: 60790
# Kolumny w danych: ['h3', 'population', 'S', 'E', 'I', 'R', 'V', 'airport', 'masks', 'lockdown', 'vaccinations', 'geometry']
#
# Tworzę obiekt mapy...
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# Dodaję dane bazowe do mapy...
#
# Dodaję dane dla poszczególnych dni...
# Dodaję dzień 0...
# - Kształt danych: (60790, 12)
# - Kolumna h3 obecna: True
# - Kolumna I obecna: True
#
# Przygotowuję konfigurację warstw...
# Dodaję konfigurację dla dnia 0...
# Tworzę końcową konfigurację mapy...
#
# Stosuje konfigurację do mapy...
#
# Zapisuję mapę do pliku pandemic_spread_2025-01-16_20-26-32\day_6.html...
# Map saved to pandemic_spread_2025-01-16_20-26-32\day_6.html!
#
# Mapa została utworzona pomyślnie!
# - Plik: day_7.geojson, Liczba zarażonych: 916914
# Rozpoczynam tworzenie mapy...
# Wczytuję dane granic państw...
# Wczytuję dane miast...
# Dane bazowe wczytane pomyślnie
# Stan początkowy - liczba rekordów: 60790
# Kolumny w danych: ['h3', 'population', 'S', 'E', 'I', 'R', 'V', 'airport', 'masks', 'lockdown', 'vaccinations', 'geometry']
#
# Tworzę obiekt mapy...
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# Dodaję dane bazowe do mapy...
#
# Dodaję dane dla poszczególnych dni...
# Dodaję dzień 0...
# - Kształt danych: (60790, 12)
# - Kolumna h3 obecna: True
# - Kolumna I obecna: True
#
# Przygotowuję konfigurację warstw...
# Dodaję konfigurację dla dnia 0...
# Tworzę końcową konfigurację mapy...
#
# Stosuje konfigurację do mapy...
#
# Zapisuję mapę do pliku pandemic_spread_2025-01-16_20-26-32\day_7.html...
# Map saved to pandemic_spread_2025-01-16_20-26-32\day_7.html!
#
# Mapa została utworzona pomyślnie!
# - Plik: day_8.geojson, Liczba zarażonych: 879169
# Rozpoczynam tworzenie mapy...
# Wczytuję dane granic państw...
# Wczytuję dane miast...
# Dane bazowe wczytane pomyślnie
# Stan początkowy - liczba rekordów: 60790
# Kolumny w danych: ['h3', 'population', 'S', 'E', 'I', 'R', 'V', 'airport', 'masks', 'lockdown', 'vaccinations', 'geometry']
#
# Tworzę obiekt mapy...
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# Dodaję dane bazowe do mapy...
#
# Dodaję dane dla poszczególnych dni...
# Dodaję dzień 0...
# - Kształt danych: (60790, 12)
# - Kolumna h3 obecna: True
# - Kolumna I obecna: True
#
# Przygotowuję konfigurację warstw...
# Dodaję konfigurację dla dnia 0...
# Tworzę końcową konfigurację mapy...
#
# Stosuje konfigurację do mapy...
#
# Zapisuję mapę do pliku pandemic_spread_2025-01-16_20-26-32\day_8.html...
# Map saved to pandemic_spread_2025-01-16_20-26-32\day_8.html!
#
# Mapa została utworzona pomyślnie!
# - Plik: day_9.geojson, Liczba zarażonych: 848574
# Rozpoczynam tworzenie mapy...
# Wczytuję dane granic państw...
# Wczytuję dane miast...
# Dane bazowe wczytane pomyślnie
# Stan początkowy - liczba rekordów: 60790
# Kolumny w danych: ['h3', 'population', 'S', 'E', 'I', 'R', 'V', 'airport', 'masks', 'lockdown', 'vaccinations', 'geometry']
#
# Tworzę obiekt mapy...
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# Dodaję dane bazowe do mapy...
#
# Dodaję dane dla poszczególnych dni...
# Dodaję dzień 0...
# - Kształt danych: (60790, 12)
# - Kolumna h3 obecna: True
# - Kolumna I obecna: True
#
# Przygotowuję konfigurację warstw...
# Dodaję konfigurację dla dnia 0...
# Tworzę końcową konfigurację mapy...
#
# Stosuje konfigurację do mapy...
#
# Zapisuję mapę do pliku pandemic_spread_2025-01-16_20-26-32\day_9.html...
# Map saved to pandemic_spread_2025-01-16_20-26-32\day_9.html!
#
# Mapa została utworzona pomyślnie!
